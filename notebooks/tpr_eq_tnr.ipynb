# %% [markdown]
# **Description**: Investigate ROC curves and similar to find good cutoff points.

# %%
import numpy as np
from gnn_tracking_hpo.util.paths import find_checkpoints, add_scripts_path

add_scripts_path()

# %%
from gnn_tracking_hpo.util.paths import get_config

checkpoint_path = find_checkpoints("ec-s9", "009d")[-1]
config = get_config("ec-s9", "009d")

# %%
config.update({"n_graphs_train": 1, "n_graphs_val": 100, "n_graphs_test": 1})

# %%
from tune_ec_sectorized import ECTrainable

# %%
trainable = ECTrainable(config)
# Out:
# DEBUG: Got config
# {'batch_size': 1,
#  'focal_alpha': 0.7397820322968228,
#  'focal_gamma': 4,
#  'gnn_tracking_experiments_hash': '1c4385064cb8472d7070c92d38d2958ab96e7485',
#  'gnn_tracking_hash': 'd1903e7319ef1dc27f2632d27212ce802d1273e2',
#  'lr': 0.00010008424753725798,
#  'lw_edge': 1.0,
#  'm_L_ec': 7,
#  'm_alpha_ec': 0.5082980468439962,
#  'm_e_dim': 4,
#  'm_h_dim': 5,
#  'm_hidden_dim': 118,
#  'm_interaction_edge_hidden_dim': 85,
#  'm_interaction_node_hidden_dim': 94,
#  'n_graphs_test': 1,
#  'n_graphs_train': 1,
#  'n_graphs_val': 100,
#  'optimizer': 'adam',
#  'scheduler': None,
#  'sector': 9,
#  'test': False,
#  'training_pt_thld': 0.0,
#  'training_without_noise': False,
#  'training_without_non_reconstructable': False}
# INFO: Loading data to cpu memory
# INFO: Loading 102 graphs (out of 371 available).
# DEBUG: Parameters for data loaders: {'batch_size': 1, 'num_workers': 12}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 trainable = ECTrainable(config)
#
# File /scratch/gpfs/kl5675/miniconda3/envs/gnn/lib/python3.10/site-packages/ray/tune/trainable/trainable.py:159, in Trainable.__init__(self, config, logger_creator, remote_checkpoint_dir, custom_syncer, sync_timeout)
#     157 start_time = time.time()
#     158 self._local_ip = ray.util.get_node_ip_address()
# --> 159 self.setup(copy.deepcopy(self.config))
#     160 setup_time = time.time() - start_time
#     161 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~/Documents/22/git_sync/hpo/src/gnn_tracking_hpo/trainable.py:220, in TCNTrainable.setup(self, config)
#     218 self.tc = config
#     219 fix_seeds()
# --> 220 self.trainer = self.get_trainer()
#
# File ~/Documents/22/git_sync/hpo/scripts/tune_ec_sectorized.py:37, in ECTrainable.get_trainer(self)
#      36 def get_trainer(self) -> TCNTrainer:
# ---> 37     trainer = super().get_trainer()
#      39     def test_every(*args, **kwargs):
#      40         if trainer._epoch % 9 == 1:
#      41             # note: first epoch we test is epoch 1
#
# File ~/Documents/22/git_sync/hpo/src/gnn_tracking_hpo/trainable.py:306, in TCNTrainable.get_trainer(self)
#     301 def get_trainer(self) -> TCNTrainer:
#     302     test = self.tc.get("test", False)
#     303     trainer = TCNTrainer(
#     304         model=self.get_model(),
#     305         loaders=self.get_loaders(),
# --> 306         loss_functions=self.get_loss_functions(),
#     307         loss_weights=self.get_loss_weights(),
#     308         lr=self.tc["lr"],
#     309         lr_scheduler=self.get_lr_scheduler(),
#     310         cluster_functions=self.get_cluster_functions(),  # type: ignore
#     311         optimizer=self.get_optimizer(),
#     312     )
#     313     trainer.max_batches_for_clustering = 100 if not test else 10
#     314     trainer.training_truth_cuts = TrainingTruthCutConfig(
#     315         without_noise=self.tc["training_without_noise"],
#     316         pt_thld=self.tc["training_pt_thld"],
#     317         without_non_reconstructable=self.tc["training_without_non_reconstructable"],
#     318     )
#
# File ~/Documents/22/git_sync/hpo/scripts/tune_ec_sectorized.py:30, in ECTrainable.get_loss_functions(self)
#      28 def get_loss_functions(self) -> dict[str, Any]:
#      29     return {
# ---> 30         "edge": self.get_edge_loss_function(),
#      31     }
#
# File ~/Documents/22/git_sync/hpo/src/gnn_tracking_hpo/trainable.py:229, in TCNTrainable.get_edge_loss_function(self)
#     227 def get_edge_loss_function(self):
#     228     return EdgeWeightFocalLoss(
# --> 229         pt_thld=self.tc["ec_pt_thld"],
#     230         alpha=self.tc["focal_alpha"],
#     231         gamma=self.tc["focal_gamma"],
#     232     )
#
# KeyError: 'ec_pt_thld'

# %%
trainable.load_checkpoint(checkpoint_path, device="cpu")

# %%
import numpy as np

output = np.array([
    0.3345,
    0.51234,
    0.8345,
    0.,
    1.
])
true = np.array([
    1,
    1,
    1,
    0,
    0
])

# %%
import torch
from gnn_tracking.metrics.binary_classification import BinaryClassificationStats

# %%
get_maximized_bcs(output=torch.from_numpy(output), y=torch.from_numpy(true))
# Out:
# {'max_ba': tensor(0.7500, dtype=torch.float64),
#  'max_f1': tensor(0.8571, dtype=torch.float64),
#  'max_mcc': tensor(0.6124, dtype=torch.float64),
#  'tpr_eq_tnr': tensor(0.5833, dtype=torch.float64),
#  'tpr_eq_tnr_at': tensor(0.3434, dtype=torch.float64)}

# %%
def find_tpr_eq_tnr(predicted, true):
    t = true.sum()
    n = len(true) - t

    thresholds = np.linspace(0., 1., 100)
    vals = []
    for thld in thresholds:
        tp = (predicted[true == 1.] >= thld).sum()
        tn = (predicted[true == 0.] < thld).sum()
        tpr = tp/t
        tnr = tn/n
        vals.append(np.abs(tpr - tnr))
    print(vals)
    idx = np.argmin(vals)
    return thresholds[idx], vals[idx]

# %%
find_tpr_eq_tnr(predicted=output, true=true)
# Out:
# [1.0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666663, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.16666666666666669, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# (0.3434343434343435, 0.16666666666666663)

# %%
from gnn_tracking.training.tcn_trainer import TCNTrainer
import torch

trainer: TCNTrainer = trainable.trainer
vals = []
with torch.no_grad():
    loader = trainer.val_loader
    for idx, data in enumerate(loader):
        print(data.y.shape)
        mo = trainer.evaluate_model(data)
        pred = mo["w"]
        true = mo["y"]
        print(true.shape)
        pts = mo["pt"]
        pids = mo["particle_id"]
        vals.append(find_tpr_eq_tnr(pred, true))
        if idx == 0:
            break
print(np.mean(vals))

# %%
def tpr_vs_tnr(predicted, true):
    t = true.sum()
    n = len(true) - t

    thresholds = np.linspace(0., 1., 1000)
    tprs = []
    tnrs = []
    for thld in thresholds:
        tp = (predicted[true == 1.] >= thld).sum()
        tn = (predicted[true == 0.] < thld).sum()
        tprs.append(tp/t)
        tnrs.append(tn/n)
    return thresholds, np.array(tprs), np.array(tnrs)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
fig, ax = plt.subplots()
for pt_thld in [-1, 0.5, 0.9, 1.5]:
    mask = trainable.trainer._edge_pt_mask(data.edge_index, pts, pt_thld)
    # value = find_tpr_eq_tnr()
    thlds, tprs, tnrs = tpr_vs_tnr(pred[mask], true[mask])
    ax.plot(tprs, tnrs, label=f"pt > {pt_thld}")
ax.plot([0., 1.], [0., 1.], ls="--", color="red", label="TPR = TNR")
ax.legend()
# Out:
# <div id='ad160037-1159-415a-9a0e-350f82e731d4'></div>

# %%
plt.plot(thlds, tprs)
plt.plot(thlds, tnrs)
