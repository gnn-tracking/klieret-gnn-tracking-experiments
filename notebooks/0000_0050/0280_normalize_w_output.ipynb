# %% [markdown]
# # Normalize W output
#
# This is an idea to backpropagate into pre-trained EC without disabling node pruning.
# To avoid the model pushing everything towards a trivial solution, we normalize the EC output.
# The threshold will then be a trainable parameter.

# %%
from typing import Any

from gnn_tracking.models.mlp import MLP
from gnn_tracking.training.tcn_trainer import TCNTrainer
from gnn_tracking.utils.graph_masks import edge_subgraph
from gnn_tracking_hpo.util.paths import add_scripts_path

from gnn_tracking.utils.loading import TrackingDataset
from torch_geometric.loader import DataLoader
import torch
from tqdm import tqdm
add_scripts_path()
from gnn_tracking_hpo.util.paths import get_config, find_checkpoint
from gnn_tracking_hpo.trainable import legacy_config_compatibility

from gnn_tracking.utils.dictionaries import subdict_with_prefix_stripped
from gnn_tracking_hpo.trainable import TCNTrainable
from torch import nn

# %%
from tune_ec import ECTrainable

# %% [markdown]
# ## Load model

# %%
project = "ec"
hash = "a94b24d1"
epoch=-1
config = legacy_config_compatibility(get_config(project, hash))
trainable = ECTrainable(config)
trainable.load_checkpoint(str(find_checkpoint(project, hash, epoch)), device="cuda")
# Out:
# [19:50:31 gnnt_hpo] DEBUG: Loading config from /home/kl5675/ray_results/ec/ECTrainable_a94b24d1_1_val_batch_size=5,adam_amsgrad=False,adam_beta1=0.9000,adam_beta2=0.9990,adam_eps=0.0000,adam_weight_decay=0_2023-04-12_22-10-45/params.json
# [19:50:31 gnnt_hpo] INFO: I'm running on a node with job ID=47035720
# [19:50:31 gnnt_hpo] WARNING: Dispatcher ID was not set. This should be set by the dispatcher as a class attribute to the trainable.
# [19:50:31 gnnt_hpo] INFO: The ID of my dispatcher is 0
# [19:50:31 SlurmControl] DEBUG: Refreshing control config from /home/kl5675/ray_slurm_control.yaml
# [19:50:31 gnnt_hpo] DEBUG: Got config
# ┌──────────────────────────────────────┬──────────────────────────────────────────┐
# │ _val_batch_size                      │ 5                                        │
# │ adam_amsgrad                         │ False                                    │
# │ adam_beta1                           │ 0.9                                      │
# │ adam_beta2                           │ 0.999                                    │
# │ adam_eps                             │ 1e-08                                    │
# │ adam_weight_decay                    │ 0.0                                      │
# │ batch_size                           │ 5                                        │
# │ ec_loss                              │ haughty_focal                            │
# │ ec_pt_thld                           │ 0.8145532232268194                       │
# │ focal_alpha                          │ 0.45                                     │
# │ focal_gamma                          │ 3.5                                      │
# │ gnn_tracking_experiments_hash        │ a63c12f7995466673e948f3338fc9bbbc9dc7b49 │
# │ gnn_tracking_hash                    │ c3b6b479b2f54f00b581c82bfd40fa6380ad17d6 │
# │ lr                                   │ 0.0006402252927288013                    │
# │ lw_edge                              │ 1.0                                      │
# │ m_L_ec                               │ 6                                        │
# │ m_alpha                              │ 0.7588635192855735                       │
# │ m_hidden_dim                         │ 120                                      │
# │ m_interaction_edge_dim               │ 120                                      │
# │ m_interaction_node_dim               │ 120                                      │
# │ m_residual_type                      │ skip1                                    │
# │ m_use_intermediate_edge_embeddings   │ True                                     │
# │ m_use_node_embedding                 │ True                                     │
# │ n_graphs_train                       │ 247776                                   │
# │ n_graphs_val                         │ 100                                      │
# │ optimizer                            │ adam                                     │
# │ scheduler                            │ None                                     │
# │ sector                               │ None                                     │
# │ test                                 │ False                                    │
# │ train_data_dir                       │ ['/scratch/gpfs/IOJALVO/gnn-tracking/obj │
# │ training_pt_thld                     │ 0.0                                      │
# │ training_without_noise               │ False                                    │
# │ training_without_non_reconstructable │ False                                    │
# │ val_data_dir                         │ /scratch/gpfs/IOJALVO/gnn-tracking/objec │
# └──────────────────────────────────────┴──────────────────────────────────────────┘
# [19:50:31 gnnt_hpo] DEBUG: Getting loaders
# [19:50:33] INFO: DataLoader will load 247776 graphs (out of 247776 available).
# [19:50:33] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_1/data21000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_8/data28999_s9.pt
# [19:50:34] INFO: DataLoader will load 100 graphs (out of 32000 available).
# [19:50:34] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9/data29000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9/data29003_s11.pt
# [19:50:34] DEBUG: Parameters for data loader 'train': {'batch_size': 5, 'num_workers': 12, 'sampler': <torch.utils.data.sampler.RandomSampler object at 0x145d06079ed0>, 'pin_memory': True}
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 6, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [19:50:34] DEBUG: Parameters for data loader 'val': {'batch_size': 5, 'num_workers': 12, 'sampler': None, 'pin_memory': True}
# [19:50:34] DEBUG: Parameters for data loader 'test': {'batch_size': 5, 'num_workers': 1, 'sampler': None, 'pin_memory': True}
# [19:50:34 TCNTrainer] INFO: Using device cuda
# [19:50:37 gnnt_hpo] DEBUG: Loading checkpoint from /home/kl5675/ray_results/ec/ECTrainable_a94b24d1_1_val_batch_size=5,adam_amsgrad=False,adam_beta1=0.9000,adam_beta2=0.9990,adam_eps=0.0000,adam_weight_decay=0_2023-04-12_22-10-45/checkpoint_000048/checkpoint.pt

# %%
ec = trainable.trainer.model

# %%
from gnn_tracking.utils.log import logger
from gnn_tracking.models.resin import ResIN
from torch_geometric.utils import index_to_mask
from torch import nn, Tensor
from torch_geometric.data import Data

class ModularGraphTCN(nn.Module):
    def __init__(
        self,
        *,
        ec: nn.Module,
        hc_in: nn.Module,
        node_indim: int,
        edge_indim: int,
        h_dim=5,
        e_dim=4,
        h_outdim=2,
        hidden_dim=40,
        feed_edge_weights=False,
        ec_threshold=0.5,
        mask_orphan_nodes=False,
        use_ec_embeddings_for_hc=False,
    ):
        """General form of track condensation network based on preconstructed graphs
        with initial step of edge classification (passed as a parameter).

        Args:
            ec: Edge classifier
            hc_in: Track condensor interaction network.
            node_indim: Node feature dimension
            edge_indim: Edge feature dimension
            h_dim: node dimension in the condensation interaction networks
            e_dim: edge dimension in the condensation interaction networks
            h_outdim: output dimension in clustering space
            hidden_dim: width of hidden layers in all perceptrons
            feed_edge_weights: whether to feed edge weights to the track condenser
            ec_threshold: threshold for edge classification
            mask_orphan_nodes: Mask nodes with no connections after EC
            use_ec_embeddings_for_hc: Use edge classifier embeddings as input to
                track condenser. This currently assumes that h_dim and e_dim are
                also the dimensions used in the EC.
        """
        super().__init__()
        self.relu = nn.ReLU()

        #: Edge classification network
        self.ec = ec
        #: Track condensation network (usually made up of interaction networks)
        self.hc_in = hc_in

        node_enc_indim = node_indim
        edge_enc_indim = edge_indim
        if use_ec_embeddings_for_hc:
            node_enc_indim += h_dim
            edge_enc_indim += e_dim
        edge_enc_indim += int(feed_edge_weights)

        #: Node encoder network for track condenser
        self.hc_node_encoder = MLP(
            node_enc_indim, h_dim, hidden_dim=hidden_dim, L=2, bias=False
        )
        #: Edge encoder network for track condenser
        self.hc_edge_encoder = MLP(
            edge_enc_indim,
            e_dim,
            hidden_dim=hidden_dim,
            L=2,
            bias=False,
        )

        #: NN to predict beta
        self.p_beta = MLP(h_dim, 1, hidden_dim, L=3)
        #: NN to predict cluster coordinates
        self.p_cluster = MLP(h_dim, h_outdim, hidden_dim, L=3)
        #: NN to predict track parameters
        # self.p_track_param = IN(
        #     node_indim=h_dim,
        #     edge_indim=e_dim + hc_in.length_concatenated_edge_attrs,
        #     node_outdim=1,
        #     edge_outdim=1,
        #     node_hidden_dim=hidden_dim,
        #     edge_hidden_dim=hidden_dim,
        # )
        self._feed_edge_weights = feed_edge_weights
        if ec_threshold == "model":
            self.threshold = nn.Parameter(torch.tensor(0.5), requires_grad=True)
        else:
            assert isinstance(ec_threshold, float)
            self.threshold = ec_threshold
        self._mask_orphan_nodes = mask_orphan_nodes
        self._use_ec_embeddings_for_hc = use_ec_embeddings_for_hc

    def forward(
        self,
        data: Data,
    ) -> dict[str, Tensor]:
        ec_result = self.ec(data)
        # Assign all EC  output to the data object, so that the cuts
        # will be applied automatically when we call `data.subgraph(...)` etc.
        data.edge_weights = ec_result["W"]
        data.ec_node_embedding = ec_result.get("node_embedding", None)
        data.ec_edge_embedding = ec_result.get("edge_embedding", None)
        edge_weights_unmasked = data.edge_weights.clone().detach()
        # ew = data.edge_weights.detach().squeeze()
        # ew = (ew - ew.mean()) / ew.std()
        edge_mask = data.edge_weights.squeeze() > self.threshold
        data = edge_subgraph(data, edge_mask)

        if self._mask_orphan_nodes:
            connected_nodes = data.edge_index.flatten().unique()
            hit_mask = index_to_mask(connected_nodes, size=data.num_nodes)
            data = data.subgraph(connected_nodes)
        else:
            hit_mask = torch.ones(
                data.num_nodes, dtype=torch.bool, device=data.x.device
            )


        logger.debug("Node survival %f. Mean w=%f threshold=%f", hit_mask.sum().item() / hit_mask.size(0), data.edge_weights.squeeze().mean(), self.threshold)

        # Get the encoded inputs for the track condenser
        _edge_attrs = [data.edge_attr]
        _xs = [data.x]
        if self._use_ec_embeddings_for_hc:
            assert data.ec_edge_embedding is not None
            assert data.ec_node_embedding is not None
            _edge_attrs.append(data.ec_edge_embedding)
            _xs.append(data.ec_node_embedding)
        if self._feed_edge_weights:
            _edge_attrs.append(data.edge_weights)
        h_hc = self.relu(self.hc_node_encoder(torch.cat(_xs, dim=1)))
        edge_attr_hc = self.relu(self.hc_edge_encoder(torch.cat(_edge_attrs, dim=1)))

        # Run the track condenser
        h_hc, _, _ = self.hc_in(h_hc, data.edge_index, edge_attr_hc)
        beta = torch.sigmoid(self.p_beta(h_hc))
        # protect against nans
        beta = beta + torch.ones_like(beta) * 10e-9

        h = self.p_cluster(h_hc)
        # track_params, _ = self.p_track_param(
        #     h_hc, data.edge_index, torch.cat(edge_attrs_hc, dim=1)
        # )
        return {
            "W": edge_weights_unmasked,
            "H": h,
            "B": beta,
            "ec_hit_mask": hit_mask,
            "ec_edge_mask": edge_mask,
        }


# Unmodified, but need to copy it here, so that the change to ModularGraphTCN is live:
class PreTrainedECGraphTCN(nn.Module):
    def __init__(
        self,
        ec,
        *,
        node_indim: int,
        edge_indim: int,
        h_dim=5,
        e_dim=4,
        h_outdim=2,
        hidden_dim=40,
        L_hc=3,
        alpha_hc: float = 0.5,
        **kwargs,
    ):
        """GraphTCN for the use with a pre-trained edge classifier

        Args:
            ec: Pre-trained edge classifier
            node_indim: Node feature dim. Determined by input data.
            edge_indim: Edge feature dim. Determined by input data.
            h_dim: node dimension after encoding
            e_dim: edge dimension after encoding
            h_outdim: output dimension in clustering space
            hidden_dim: dimension of hidden layers in all MLPs used in the interaction
                networks
            L_hc: message passing depth for track condenser
            alpha_hc: strength of residual connection for multi-layer interaction
                networks
        """
        super().__init__()
        hc_in = ResIN(
            node_dim=h_dim,
            edge_dim=e_dim,
            object_hidden_dim=hidden_dim,
            relational_hidden_dim=hidden_dim,
            alpha=alpha_hc,
            n_layers=L_hc,
        )
        self._gtcn = ModularGraphTCN(
            ec=ec,
            hc_in=hc_in,
            node_indim=node_indim,
            edge_indim=edge_indim,
            h_dim=h_dim,
            e_dim=e_dim,
            h_outdim=h_outdim,
            hidden_dim=hidden_dim,
            **kwargs,
        )

    def forward(
        self,
        data: Data,
    ) -> dict[str, Tensor]:
        return self._gtcn.forward(data=data)

# %%
# Stupid modification that just takes the globally defined EC
class PretrainedECTrainable(TCNTrainable):
    def get_loss_functions(self) -> dict[str, Any]:
        return {
            "potential": self.get_potential_loss_function(),
            "background": self.get_background_loss_function(),
        }

    def get_trainer(self) -> TCNTrainer:
        trainer = super().get_trainer()
        trainer.ec_threshold = self.tc["m_ec_threshold"]
        return trainer

    def get_model(self) -> nn.Module:
        return PreTrainedECGraphTCN(
            ec,
            node_indim=7,
            edge_indim=4,
            **subdict_with_prefix_stripped(self.tc, "m_"),
        )

# %%
import optuna
from gnn_tracking_hpo.config import get_metadata, auto_suggest_if_not_fixed
from gnn_tracking_hpo.trainable import suggest_default_values


def suggest_config(
    trial: optuna.Trial,
    *,
    sector= None,
    ec_project: str,
    ec_hash: str,
    ec_epoch: int = -1,
    test=False,
    fixed= None,
) -> dict[str, Any]:
    config = get_metadata(test=test)
    config.update(fixed or {})

    def d(key, *args, **kwargs):
        auto_suggest_if_not_fixed(key, config, trial, *args, **kwargs)

    # Definitely Fixed hyperparameters
    # --------------------------------

    d("n_graphs_train", 247776)
    config["train_data_dir"] = [
        f"/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_{i}"
        for i in range(1, 9)
    ]
    d(
        "val_data_dir",
        "/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9",
    )
    d("sector", sector)

    d("m_mask_orphan_nodes", True)
    d("use_ec_embeddings_for_hc", True)
    d("feed_edge_weights", True)
    d("m_ec_threshold", "model")

    d("ec_project", ec_project)
    d("ec_hash", ec_hash)
    d("ec_epoch", ec_epoch)

    d("batch_size", 5)

    # Keep one fixed because of normalization invariance
    d("lw_potential_attractive", 1.0)

    d("m_hidden_dim", 120)
    d("m_h_dim", 120)
    d("m_e_dim", 120)

    # Most of the following parameters are fixed based on af5b5461

    d("attr_pt_thld", 0.6)
    d("q_min", 0.34)
    d("sb", 0.09)
    d("m_alpha_hc", 0.63)
    d("lw_background", 0.0041)
    d("lw_potential_repulsive", 0.16)
    d("repulsive_radius_threshold", 3.7)
    d("m_h_outdim", 7)

    # Tuned hyperparameters
    # ---------------------

    d("m_ec_threshold", 0.1, 0.5)
    d("lr", 0.0001, 0.0010)
    d("m_L_hc", 3, 5)

    suggest_default_values(config, trial, ec="fixed")
    print(config)
    print(trial.params)
    return config

# %%
study = optuna.create_study(direction="maximize")
trial = study.ask()
_config = suggest_config(trial=trial, ec_project=project, ec_hash=hash, ec_epoch=epoch, test=False)
config = _config | trial.params
config["batch_size"] = 1
trainable = PretrainedECTrainable(config)
trainer = trainable.trainer
# Out:
# [I 2023-04-18 20:18:25,620] A new study created in memory with name: no-name-4af86ca2-79ed-4f27-b339-5f83824464f8
# [20:18:25] WARNING: Repository /home/kl5675/Documents/23/git_sync/gnn_tracking/src/gnn_tracking is dirty, commit hash may not be accurate.
# [20:18:25] WARNING: Repository /home/kl5675/Documents/23/git_sync/hpo/src/gnn_tracking_hpo is dirty, commit hash may not be accurate.
# [20:18:25 gnnt_hpo] INFO: I'm running on a node with job ID=47035720
# [20:18:25 gnnt_hpo] WARNING: Dispatcher ID was not set. This should be set by the dispatcher as a class attribute to the trainable.
# [20:18:25 gnnt_hpo] INFO: The ID of my dispatcher is 0
# [20:18:25 SlurmControl] DEBUG: Refreshing control config from /home/kl5675/ray_slurm_control.yaml
# [20:18:25 gnnt_hpo] DEBUG: Got config
# ┌───────────────────────────────┬──────────────────────────────────────────┐
# │ _val_batch_size               │ 1                                        │
# │ adam_amsgrad                  │ False                                    │
# │ adam_beta1                    │ 0.9                                      │
# │ adam_beta2                    │ 0.999                                    │
# │ adam_eps                      │ 1e-08                                    │
# │ adam_weight_decay             │ 0.0                                      │
# │ attr_pt_thld                  │ 0.6                                      │
# │ batch_size                    │ 1                                        │
# │ ec_epoch                      │ -1                                       │
# │ ec_hash                       │ a94b24d1                                 │
# │ ec_loss                       │ focal                                    │
# │ ec_project                    │ ec                                       │
# │ ec_pt_thld                    │ 0.0                                      │
# │ edge_indim                    │ 4                                        │
# │ feed_edge_weights             │ True                                     │
# │ gnn_tracking_experiments_hash │ 41dda2253ce999deb42d519115dd2e7bd0f3b83c │
# │ gnn_tracking_hash             │ d765620dde9582e8f229334f60f58bf182ff0e10 │
# │ lr                            │ 0.00026609921678741414                   │
# │ lw_background                 │ 0.0041                                   │
# │ lw_potential_attractive       │ 1.0                                      │
# │ lw_potential_repulsive        │ 0.16                                     │
# │ m_L_hc                        │ 4                                        │
# │ m_alpha_hc                    │ 0.63                                     │
# │ m_e_dim                       │ 120                                      │
# │ m_ec_threshold                │ model                                    │
# │ m_h_dim                       │ 120                                      │
# │ m_h_outdim                    │ 7                                        │
# │ m_hidden_dim                  │ 120                                      │
# │ m_mask_orphan_nodes           │ True                                     │
# │ n_graphs_train                │ 247776                                   │
# │ n_graphs_val                  │ 400                                      │
# │ node_indim                    │ 7                                        │
# │ optimizer                     │ adam                                     │
# │ q_min                         │ 0.34                                     │
# │ repulsive_radius_threshold    │ 3.7                                      │
# │ sb                            │ 0.09                                     │
# │ scheduler                     │ None                                     │
# │ sector                        │ None                                     │
# │ test                          │ False                                    │
# │ train_data_dir                │ ['/scratch/gpfs/IOJALVO/gnn-tracking/obj │
# │ use_ec_embeddings_for_hc      │ True                                     │
# │ val_data_dir                  │ /scratch/gpfs/IOJALVO/gnn-tracking/objec │
# └───────────────────────────────┴──────────────────────────────────────────┘
# [20:18:25 gnnt_hpo] DEBUG: Getting loaders
# {'test': False, 'gnn_tracking_hash': 'd765620dde9582e8f229334f60f58bf182ff0e10', 'gnn_tracking_experiments_hash': '41dda2253ce999deb42d519115dd2e7bd0f3b83c', 'n_graphs_train': 247776, 'train_data_dir': ['/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_1', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_2', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_3', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_4', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_5', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_6', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_7', '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_8'], 'val_data_dir': '/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9', 'sector': None, 'm_mask_orphan_nodes': True, 'use_ec_embeddings_for_hc': True, 'feed_edge_weights': True, 'm_ec_threshold': 'model', 'ec_project': 'ec', 'ec_hash': 'a94b24d1', 'ec_epoch': -1, 'batch_size': 5, 'lw_potential_attractive': 1.0, 'm_hidden_dim': 120, 'm_h_dim': 120, 'm_e_dim': 120, 'attr_pt_thld': 0.6, 'q_min': 0.34, 'sb': 0.09, 'm_alpha_hc': 0.63, 'lw_background': 0.0041, 'lw_potential_repulsive': 0.16, 'repulsive_radius_threshold': 3.7, 'm_h_outdim': 7, 'node_indim': 7, 'edge_indim': 4, 'n_graphs_val': 400, 'ec_pt_thld': 0.0, '_val_batch_size': 1, 'ec_loss': 'focal', 'optimizer': 'adam', 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'adam_eps': 1e-08, 'adam_weight_decay': 0.0, 'adam_amsgrad': False, 'scheduler': None}
# {'lr': 0.00026609921678741414, 'm_L_hc': 4}
# [20:18:28] INFO: DataLoader will load 247776 graphs (out of 247776 available).
# [20:18:28] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_1/data21000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_8/data28999_s9.pt
# [20:18:28] INFO: DataLoader will load 400 graphs (out of 32000 available).
# [20:18:28] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9/data29000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/graphs_v1/part_9/data29012_s22.pt
# [20:18:28] DEBUG: Parameters for data loader 'train': {'batch_size': 1, 'num_workers': 12, 'sampler': <torch.utils.data.sampler.RandomSampler object at 0x1459a62513f0>, 'pin_memory': True}
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 6, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [20:18:28] DEBUG: Parameters for data loader 'val': {'batch_size': 1, 'num_workers': 12, 'sampler': None, 'pin_memory': True}
# [20:18:28] DEBUG: Parameters for data loader 'test': {'batch_size': 1, 'num_workers': 1, 'sampler': None, 'pin_memory': True}
# [20:18:28 TCNTrainer] INFO: Using device cuda

# %%
import os
os.environ["PYTORCH_NVFUSER_DISABLE"] = ""
trainer.train_step()
# Out:
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch_geometric/data/collate.py:145: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = elem.storage()._new_shared(numel)
# [20:18:29] DEBUG: Node survival 0.386211. Mean w=0.810601 threshold=0.500000
# [20:18:29 TCNTrainer] INFO: Epoch  0 (    0/12000): potential_attractive_weighted=   0.00020, potential_repulsive_weighted=  22.51263, background_weighted=   0.00229
# [20:18:29] DEBUG: Node survival 0.319648. Mean w=0.816938 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.320994. Mean w=0.803400 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.326509. Mean w=0.834998 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.348073. Mean w=0.799745 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.410237. Mean w=0.827521 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.325725. Mean w=0.805929 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.355556. Mean w=0.796888 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.365385. Mean w=0.819114 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.335755. Mean w=0.812520 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.327968. Mean w=0.793571 threshold=0.500000
# [20:18:29 TCNTrainer] INFO: Epoch  0 (   10/12000): potential_attractive_weighted=   0.00082, potential_repulsive_weighted=  23.10989, background_weighted=   0.00222
# [20:18:29] DEBUG: Node survival 0.374035. Mean w=0.817071 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.322227. Mean w=0.782723 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.294262. Mean w=0.813218 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.376606. Mean w=0.789892 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.289236. Mean w=0.789890 threshold=0.500000
# [20:18:29] DEBUG: Node survival 0.319102. Mean w=0.781191 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.253583. Mean w=0.814841 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.392933. Mean w=0.823784 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.278680. Mean w=0.823261 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.253170. Mean w=0.792159 threshold=0.500000
# [20:18:30 TCNTrainer] INFO: Epoch  0 (   20/12000): potential_attractive_weighted=   0.00673, potential_repulsive_weighted=  16.74243, background_weighted=   0.00251
# [20:18:30] DEBUG: Node survival 0.342721. Mean w=0.797578 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.384427. Mean w=0.848069 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.361521. Mean w=0.829105 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.367490. Mean w=0.818920 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.325229. Mean w=0.801381 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.383929. Mean w=0.813065 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.383182. Mean w=0.818125 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.279645. Mean w=0.809548 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.300703. Mean w=0.799861 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.315257. Mean w=0.806043 threshold=0.500000
# [20:18:30 TCNTrainer] INFO: Epoch  0 (   30/12000): potential_attractive_weighted=   0.19944, potential_repulsive_weighted=   8.20455, background_weighted=   0.00289
# [20:18:30] DEBUG: Node survival 0.374902. Mean w=0.795565 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.422866. Mean w=0.837926 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.303752. Mean w=0.779083 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.334028. Mean w=0.808899 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.305254. Mean w=0.771178 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.356403. Mean w=0.814350 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.296069. Mean w=0.796221 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.307176. Mean w=0.795232 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.331768. Mean w=0.793956 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.366320. Mean w=0.822581 threshold=0.500000
# [20:18:30 TCNTrainer] INFO: Epoch  0 (   40/12000): potential_attractive_weighted=   1.60924, potential_repulsive_weighted=   4.55059, background_weighted=   0.00334
# [20:18:30] DEBUG: Node survival 0.312771. Mean w=0.796373 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.337945. Mean w=0.801739 threshold=0.500000
# [20:18:30] DEBUG: Node survival 0.339119. Mean w=0.800356 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.323917. Mean w=0.802590 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.333076. Mean w=0.807611 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.358785. Mean w=0.820055 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.303241. Mean w=0.792738 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.320397. Mean w=0.816857 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.416529. Mean w=0.826754 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.344094. Mean w=0.813664 threshold=0.500000
# [20:18:31 TCNTrainer] INFO: Epoch  0 (   50/12000): potential_attractive_weighted=   0.37188, potential_repulsive_weighted=   6.12105, background_weighted=   0.00357
# [20:18:31] DEBUG: Node survival 0.252083. Mean w=0.816818 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.289336. Mean w=0.822923 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.239766. Mean w=0.748374 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.354185. Mean w=0.797509 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.289189. Mean w=0.780144 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.312118. Mean w=0.807442 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.326165. Mean w=0.803473 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.441286. Mean w=0.816693 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.330357. Mean w=0.760056 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.332359. Mean w=0.780536 threshold=0.500000
# [20:18:31 TCNTrainer] INFO: Epoch  0 (   60/12000): potential_attractive_weighted=   0.78316, potential_repulsive_weighted=   2.99951, background_weighted=   0.00379
# [20:18:31] DEBUG: Node survival 0.348239. Mean w=0.825255 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.345161. Mean w=0.801475 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.390794. Mean w=0.819657 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.313330. Mean w=0.802730 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.322265. Mean w=0.798098 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.374412. Mean w=0.819094 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.370919. Mean w=0.805541 threshold=0.500000
# [20:18:31] DEBUG: Node survival 0.401034. Mean w=0.832336 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.325411. Mean w=0.803618 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.298863. Mean w=0.822007 threshold=0.500000
# [20:18:32 TCNTrainer] INFO: Epoch  0 (   70/12000): potential_attractive_weighted=   0.84662, potential_repulsive_weighted=   2.69898, background_weighted=   0.00395
# [20:18:32] DEBUG: Node survival 0.365844. Mean w=0.815294 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.367928. Mean w=0.807046 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.310209. Mean w=0.771251 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.327560. Mean w=0.771833 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.364195. Mean w=0.827334 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.366215. Mean w=0.818993 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.318200. Mean w=0.766719 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.356260. Mean w=0.814440 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.367475. Mean w=0.818938 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.324621. Mean w=0.812071 threshold=0.500000
# [20:18:32 TCNTrainer] INFO: Epoch  0 (   80/12000): potential_attractive_weighted=   0.88581, potential_repulsive_weighted=   3.61857, background_weighted=   0.00393
# [20:18:32] DEBUG: Node survival 0.363798. Mean w=0.834131 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.392504. Mean w=0.810159 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.279773. Mean w=0.770151 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.370597. Mean w=0.820628 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.382497. Mean w=0.814451 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.314600. Mean w=0.753039 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.282292. Mean w=0.778513 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.321401. Mean w=0.820164 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.319068. Mean w=0.797498 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.297017. Mean w=0.812315 threshold=0.500000
# [20:18:32 TCNTrainer] INFO: Epoch  0 (   90/12000): potential_attractive_weighted=   1.07832, potential_repulsive_weighted=   3.06467, background_weighted=   0.00398
# [20:18:32] DEBUG: Node survival 0.329428. Mean w=0.774875 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.306868. Mean w=0.783766 threshold=0.500000
# [20:18:32] DEBUG: Node survival 0.382601. Mean w=0.812915 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.345707. Mean w=0.810378 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.263134. Mean w=0.774749 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.432000. Mean w=0.822454 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.376494. Mean w=0.804702 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.313662. Mean w=0.815377 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.292084. Mean w=0.791041 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.386241. Mean w=0.795669 threshold=0.500000
# [20:18:33 TCNTrainer] INFO: Epoch  0 (  100/12000): potential_attractive_weighted=   1.26441, potential_repulsive_weighted=   2.45391, background_weighted=   0.00401
# [20:18:33] DEBUG: Node survival 0.348279. Mean w=0.839048 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.361371. Mean w=0.816277 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.321311. Mean w=0.785826 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.356493. Mean w=0.805331 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.305126. Mean w=0.806875 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.327505. Mean w=0.798323 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.361582. Mean w=0.808490 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.351744. Mean w=0.799292 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.324185. Mean w=0.809205 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.373399. Mean w=0.820016 threshold=0.500000
# [20:18:33 TCNTrainer] INFO: Epoch  0 (  110/12000): potential_attractive_weighted=   0.99769, potential_repulsive_weighted=   3.49254, background_weighted=   0.00402
# [20:18:33] DEBUG: Node survival 0.334448. Mean w=0.805526 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.410091. Mean w=0.816816 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.423241. Mean w=0.841391 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.314286. Mean w=0.794168 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.382411. Mean w=0.813307 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.338964. Mean w=0.833095 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.371826. Mean w=0.820190 threshold=0.500000
# [20:18:33] DEBUG: Node survival 0.339018. Mean w=0.838808 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.348491. Mean w=0.798284 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.387969. Mean w=0.802413 threshold=0.500000
# [20:18:34 TCNTrainer] INFO: Epoch  0 (  120/12000): potential_attractive_weighted=   0.80246, potential_repulsive_weighted=   3.56875, background_weighted=   0.00405
# [20:18:34] DEBUG: Node survival 0.337575. Mean w=0.801051 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.322118. Mean w=0.803297 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.370103. Mean w=0.793959 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.326335. Mean w=0.806490 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.382243. Mean w=0.792194 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.360000. Mean w=0.824656 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.348877. Mean w=0.808752 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.379358. Mean w=0.820271 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.324269. Mean w=0.823718 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.350476. Mean w=0.784666 threshold=0.500000
# [20:18:34 TCNTrainer] INFO: Epoch  0 (  130/12000): potential_attractive_weighted=   0.77900, potential_repulsive_weighted=   3.22570, background_weighted=   0.00404
# [20:18:34] DEBUG: Node survival 0.273352. Mean w=0.796147 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.305797. Mean w=0.793918 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.355427. Mean w=0.810721 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.291080. Mean w=0.783261 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.334361. Mean w=0.776024 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.394060. Mean w=0.819770 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.353163. Mean w=0.805625 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.356539. Mean w=0.825583 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.262972. Mean w=0.805223 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.289211. Mean w=0.774347 threshold=0.500000
# [20:18:34 TCNTrainer] INFO: Epoch  0 (  140/12000): potential_attractive_weighted=   0.80216, potential_repulsive_weighted=   2.15953, background_weighted=   0.00407
# [20:18:34] DEBUG: Node survival 0.304298. Mean w=0.794032 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.365736. Mean w=0.818208 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.321939. Mean w=0.802367 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.358090. Mean w=0.827570 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.322379. Mean w=0.803911 threshold=0.500000
# [20:18:34] DEBUG: Node survival 0.334272. Mean w=0.800400 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.361833. Mean w=0.809256 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.322639. Mean w=0.760418 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.313814. Mean w=0.797504 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.390805. Mean w=0.784584 threshold=0.500000
# [20:18:35 TCNTrainer] INFO: Epoch  0 (  150/12000): potential_attractive_weighted=   0.86658, potential_repulsive_weighted=   3.24830, background_weighted=   0.00408
# [20:18:35] DEBUG: Node survival 0.354028. Mean w=0.817951 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.307330. Mean w=0.806711 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.359565. Mean w=0.810620 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.342478. Mean w=0.797182 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.380597. Mean w=0.824104 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.327398. Mean w=0.802934 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.341856. Mean w=0.798549 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.383850. Mean w=0.816998 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.346867. Mean w=0.827517 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.312470. Mean w=0.787279 threshold=0.500000
# [20:18:35 TCNTrainer] INFO: Epoch  0 (  160/12000): potential_attractive_weighted=   1.04478, potential_repulsive_weighted=   1.52698, background_weighted=   0.00409
# [20:18:35] DEBUG: Node survival 0.342356. Mean w=0.798672 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.344741. Mean w=0.806248 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.328852. Mean w=0.809611 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.366928. Mean w=0.832137 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.320048. Mean w=0.815227 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.279097. Mean w=0.799003 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.291621. Mean w=0.790040 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.439169. Mean w=0.824202 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.315439. Mean w=0.808188 threshold=0.500000
# [20:18:35] DEBUG: Node survival 0.301599. Mean w=0.779793 threshold=0.500000
# [20:18:35 TCNTrainer] INFO: Epoch  0 (  170/12000): potential_attractive_weighted=   1.18098, potential_repulsive_weighted=   1.65754, background_weighted=   0.00409
# [20:18:36] DEBUG: Node survival 0.316341. Mean w=0.802485 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.364300. Mean w=0.808484 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.425918. Mean w=0.801670 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.300699. Mean w=0.792843 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.315834. Mean w=0.774394 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.359170. Mean w=0.813336 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.321051. Mean w=0.802871 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.399920. Mean w=0.804368 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.429697. Mean w=0.810265 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.322593. Mean w=0.795555 threshold=0.500000
# [20:18:36 TCNTrainer] INFO: Epoch  0 (  180/12000): potential_attractive_weighted=   1.13031, potential_repulsive_weighted=   1.90371, background_weighted=   0.00410
# [20:18:36] DEBUG: Node survival 0.313924. Mean w=0.816659 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.303112. Mean w=0.818049 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.333333. Mean w=0.802134 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.345151. Mean w=0.833888 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.305556. Mean w=0.800651 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.315766. Mean w=0.795380 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.343012. Mean w=0.816561 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.386441. Mean w=0.821284 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.294634. Mean w=0.835998 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.335144. Mean w=0.825838 threshold=0.500000
# [20:18:36 TCNTrainer] INFO: Epoch  0 (  190/12000): potential_attractive_weighted=   0.90236, potential_repulsive_weighted=   1.20171, background_weighted=   0.00410
# [20:18:36] DEBUG: Node survival 0.309804. Mean w=0.801062 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.318396. Mean w=0.823530 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.297184. Mean w=0.814331 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.335209. Mean w=0.762523 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.361276. Mean w=0.799025 threshold=0.500000
# [20:18:36] DEBUG: Node survival 0.313131. Mean w=0.814028 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.322034. Mean w=0.766886 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.324700. Mean w=0.798115 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.336551. Mean w=0.788654 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.377799. Mean w=0.843055 threshold=0.500000
# [20:18:37 TCNTrainer] INFO: Epoch  0 (  200/12000): potential_attractive_weighted=   0.72300, potential_repulsive_weighted=   1.51365, background_weighted=   0.00410
# [20:18:37] DEBUG: Node survival 0.291062. Mean w=0.797512 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.267292. Mean w=0.771104 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.381483. Mean w=0.834540 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.346375. Mean w=0.834302 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.221563. Mean w=0.758604 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.272607. Mean w=0.791461 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.336527. Mean w=0.824722 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.400621. Mean w=0.817204 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.353611. Mean w=0.800898 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.255860. Mean w=0.786110 threshold=0.500000
# [20:18:37 TCNTrainer] INFO: Epoch  0 (  210/12000): potential_attractive_weighted=   0.88514, potential_repulsive_weighted=   1.43126, background_weighted=   0.00410
# [20:18:37] DEBUG: Node survival 0.339735. Mean w=0.807781 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.310803. Mean w=0.836014 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.383269. Mean w=0.810305 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.340876. Mean w=0.806928 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.407952. Mean w=0.800148 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.293785. Mean w=0.772262 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.382848. Mean w=0.809081 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.349266. Mean w=0.801821 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.332304. Mean w=0.807136 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.324736. Mean w=0.803037 threshold=0.500000
# [20:18:37 TCNTrainer] INFO: Epoch  0 (  220/12000): potential_attractive_weighted=   1.22460, potential_repulsive_weighted=   1.02017, background_weighted=   0.00410
# [20:18:37] DEBUG: Node survival 0.238260. Mean w=0.770097 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.240795. Mean w=0.781700 threshold=0.500000
# [20:18:37] DEBUG: Node survival 0.312646. Mean w=0.790081 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.319596. Mean w=0.798469 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.341990. Mean w=0.801995 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.365921. Mean w=0.837644 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.408813. Mean w=0.830900 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.310618. Mean w=0.815880 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.289213. Mean w=0.794375 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.349318. Mean w=0.818455 threshold=0.500000
# [20:18:38 TCNTrainer] INFO: Epoch  0 (  230/12000): potential_attractive_weighted=   0.81353, potential_repulsive_weighted=   1.79160, background_weighted=   0.00410
# [20:18:38] DEBUG: Node survival 0.362124. Mean w=0.799313 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.289555. Mean w=0.797397 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.381029. Mean w=0.844608 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.414452. Mean w=0.819623 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.395072. Mean w=0.798786 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.331293. Mean w=0.804460 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.379049. Mean w=0.825554 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.319422. Mean w=0.806064 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.332507. Mean w=0.790931 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.327344. Mean w=0.799221 threshold=0.500000
# [20:18:38 TCNTrainer] INFO: Epoch  0 (  240/12000): potential_attractive_weighted=   0.59910, potential_repulsive_weighted=   1.53437, background_weighted=   0.00410
# [20:18:38] DEBUG: Node survival 0.383377. Mean w=0.794715 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.308477. Mean w=0.786793 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.281440. Mean w=0.811085 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.318644. Mean w=0.798855 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.323214. Mean w=0.810383 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.313613. Mean w=0.804034 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.284668. Mean w=0.797245 threshold=0.500000
# [20:18:38] DEBUG: Node survival 0.289867. Mean w=0.791896 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.394076. Mean w=0.807274 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.295266. Mean w=0.774739 threshold=0.500000
# [20:18:39 TCNTrainer] INFO: Epoch  0 (  250/12000): potential_attractive_weighted=   0.47084, potential_repulsive_weighted=   1.82994, background_weighted=   0.00410
# [20:18:39] DEBUG: Node survival 0.351436. Mean w=0.801387 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.274816. Mean w=0.799223 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.314076. Mean w=0.797044 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.365478. Mean w=0.807434 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.357036. Mean w=0.803739 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.267895. Mean w=0.780747 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.337167. Mean w=0.813882 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.306743. Mean w=0.784187 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.318026. Mean w=0.815560 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.378934. Mean w=0.829317 threshold=0.500000
# [20:18:39 TCNTrainer] INFO: Epoch  0 (  260/12000): potential_attractive_weighted=   0.81029, potential_repulsive_weighted=   1.01062, background_weighted=   0.00410
# [20:18:39] DEBUG: Node survival 0.281326. Mean w=0.786468 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.298910. Mean w=0.774231 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.391953. Mean w=0.817376 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.331765. Mean w=0.806701 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.366667. Mean w=0.819048 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.351721. Mean w=0.808101 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.352718. Mean w=0.814994 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.421563. Mean w=0.799847 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.353396. Mean w=0.780988 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.243213. Mean w=0.807163 threshold=0.500000
# [20:18:39 TCNTrainer] INFO: Epoch  0 (  270/12000): potential_attractive_weighted=   0.47176, potential_repulsive_weighted=   0.80709, background_weighted=   0.00410
# [20:18:39] DEBUG: Node survival 0.341373. Mean w=0.817793 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.367717. Mean w=0.844175 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.352621. Mean w=0.794193 threshold=0.500000
# [20:18:39] DEBUG: Node survival 0.261180. Mean w=0.773664 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.349814. Mean w=0.790035 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.310484. Mean w=0.790957 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.321269. Mean w=0.779705 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.373503. Mean w=0.812403 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.305751. Mean w=0.780312 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.321949. Mean w=0.805113 threshold=0.500000
# [20:18:40 TCNTrainer] INFO: Epoch  0 (  280/12000): potential_attractive_weighted=   0.51312, potential_repulsive_weighted=   1.14670, background_weighted=   0.00410
# [20:18:40] DEBUG: Node survival 0.379052. Mean w=0.782428 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.375380. Mean w=0.835702 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.340899. Mean w=0.814419 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.345695. Mean w=0.810780 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.372452. Mean w=0.825237 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.297022. Mean w=0.790268 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.404649. Mean w=0.827597 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.321349. Mean w=0.811809 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.355784. Mean w=0.859927 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.362472. Mean w=0.812170 threshold=0.500000
# [20:18:40 TCNTrainer] INFO: Epoch  0 (  290/12000): potential_attractive_weighted=   0.68239, potential_repulsive_weighted=   0.70737, background_weighted=   0.00410
# [20:18:40] DEBUG: Node survival 0.301117. Mean w=0.805974 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.336607. Mean w=0.786400 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.311216. Mean w=0.799060 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.310636. Mean w=0.781193 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.290135. Mean w=0.787138 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.375106. Mean w=0.838423 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.350908. Mean w=0.782184 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.272192. Mean w=0.813589 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.372981. Mean w=0.816309 threshold=0.500000
# [20:18:40] DEBUG: Node survival 0.304152. Mean w=0.795043 threshold=0.500000
# [20:18:40 TCNTrainer] INFO: Epoch  0 (  300/12000): potential_attractive_weighted=   0.40737, potential_repulsive_weighted=   0.77784, background_weighted=   0.00410
# [20:18:41] DEBUG: Node survival 0.294666. Mean w=0.828058 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.367980. Mean w=0.813763 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.371303. Mean w=0.799372 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.303387. Mean w=0.806057 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.279059. Mean w=0.789046 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.416634. Mean w=0.814043 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.366745. Mean w=0.821496 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.409508. Mean w=0.826810 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.339232. Mean w=0.815836 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.379903. Mean w=0.802279 threshold=0.500000
# [20:18:41 TCNTrainer] INFO: Epoch  0 (  310/12000): potential_attractive_weighted=   0.43507, potential_repulsive_weighted=   0.86218, background_weighted=   0.00410
# [20:18:41] DEBUG: Node survival 0.307295. Mean w=0.806329 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.313932. Mean w=0.804532 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.420449. Mean w=0.805728 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.348078. Mean w=0.784974 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.289430. Mean w=0.780828 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.403670. Mean w=0.813068 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.271077. Mean w=0.785142 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.353568. Mean w=0.822841 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.302298. Mean w=0.831998 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.292503. Mean w=0.813149 threshold=0.500000
# [20:18:41 TCNTrainer] INFO: Epoch  0 (  320/12000): potential_attractive_weighted=   0.28250, potential_repulsive_weighted=   0.90036, background_weighted=   0.00410
# [20:18:41] DEBUG: Node survival 0.322097. Mean w=0.798368 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.353152. Mean w=0.817876 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.253260. Mean w=0.774664 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.403877. Mean w=0.818097 threshold=0.500000
# [20:18:41] DEBUG: Node survival 0.341296. Mean w=0.826255 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.376844. Mean w=0.822389 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.346574. Mean w=0.801759 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.316390. Mean w=0.797670 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.304152. Mean w=0.784703 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.305567. Mean w=0.784955 threshold=0.500000
# [20:18:42 TCNTrainer] INFO: Epoch  0 (  330/12000): potential_attractive_weighted=   0.47758, potential_repulsive_weighted=   0.80936, background_weighted=   0.00410
# [20:18:42] DEBUG: Node survival 0.312470. Mean w=0.787279 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.385021. Mean w=0.822176 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.379729. Mean w=0.812273 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.273623. Mean w=0.761696 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.313777. Mean w=0.784656 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.362516. Mean w=0.817483 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.318738. Mean w=0.793662 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.377308. Mean w=0.800878 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.405312. Mean w=0.819776 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.350936. Mean w=0.808267 threshold=0.500000
# [20:18:42 TCNTrainer] INFO: Epoch  0 (  340/12000): potential_attractive_weighted=   0.36421, potential_repulsive_weighted=   0.94010, background_weighted=   0.00410
# [20:18:42] DEBUG: Node survival 0.281440. Mean w=0.811085 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.314250. Mean w=0.800497 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.369612. Mean w=0.814341 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.305659. Mean w=0.780517 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.278005. Mean w=0.777418 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.321050. Mean w=0.817342 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.268409. Mean w=0.792407 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.302518. Mean w=0.760127 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.383628. Mean w=0.810756 threshold=0.500000
# [20:18:42] DEBUG: Node survival 0.352694. Mean w=0.826912 threshold=0.500000
# [20:18:42 TCNTrainer] INFO: Epoch  0 (  350/12000): potential_attractive_weighted=   0.38059, potential_repulsive_weighted=   0.86825, background_weighted=   0.00410
# [20:18:43] DEBUG: Node survival 0.264804. Mean w=0.799709 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.348665. Mean w=0.800267 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.337303. Mean w=0.822784 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.338793. Mean w=0.830734 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.380739. Mean w=0.837193 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.410700. Mean w=0.843214 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.316040. Mean w=0.785213 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.266038. Mean w=0.791790 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.369882. Mean w=0.829178 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.306683. Mean w=0.806977 threshold=0.500000
# [20:18:43 TCNTrainer] INFO: Epoch  0 (  360/12000): potential_attractive_weighted=   0.40415, potential_repulsive_weighted=   0.35729, background_weighted=   0.00410
# [20:18:43] DEBUG: Node survival 0.390632. Mean w=0.801720 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.299183. Mean w=0.736153 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.345767. Mean w=0.802300 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.330259. Mean w=0.799667 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.360839. Mean w=0.828062 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.358791. Mean w=0.804979 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.399787. Mean w=0.816016 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.300678. Mean w=0.819603 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.379781. Mean w=0.808642 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.287879. Mean w=0.811813 threshold=0.500000
# [20:18:43 TCNTrainer] INFO: Epoch  0 (  370/12000): potential_attractive_weighted=   0.31959, potential_repulsive_weighted=   0.72259, background_weighted=   0.00410
# [20:18:43] DEBUG: Node survival 0.348390. Mean w=0.836660 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.323760. Mean w=0.821269 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.353925. Mean w=0.799734 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.378151. Mean w=0.837012 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.361562. Mean w=0.821670 threshold=0.500000
# [20:18:43] DEBUG: Node survival 0.319679. Mean w=0.821742 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.307428. Mean w=0.804493 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.416885. Mean w=0.822451 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.340573. Mean w=0.794296 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.345998. Mean w=0.803155 threshold=0.500000
# [20:18:44 TCNTrainer] INFO: Epoch  0 (  380/12000): potential_attractive_weighted=   0.65455, potential_repulsive_weighted=   0.56547, background_weighted=   0.00410
# [20:18:44] DEBUG: Node survival 0.298362. Mean w=0.797160 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.348163. Mean w=0.787343 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.307784. Mean w=0.787780 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.421345. Mean w=0.802846 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.358131. Mean w=0.769114 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.334585. Mean w=0.794499 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.351590. Mean w=0.819121 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.279611. Mean w=0.790173 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.352998. Mean w=0.784090 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.338501. Mean w=0.810204 threshold=0.500000
# [20:18:44 TCNTrainer] INFO: Epoch  0 (  390/12000): potential_attractive_weighted=   0.31628, potential_repulsive_weighted=   0.62879, background_weighted=   0.00410
# [20:18:44] DEBUG: Node survival 0.424118. Mean w=0.801388 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.283234. Mean w=0.800059 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.380129. Mean w=0.803949 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.369068. Mean w=0.824012 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.349130. Mean w=0.807175 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.324135. Mean w=0.783962 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.350344. Mean w=0.809267 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.311823. Mean w=0.805450 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.364574. Mean w=0.811497 threshold=0.500000
# [20:18:44] DEBUG: Node survival 0.348331. Mean w=0.804697 threshold=0.500000
# [20:18:44 TCNTrainer] INFO: Epoch  0 (  400/12000): potential_attractive_weighted=   0.31769, potential_repulsive_weighted=   0.65988, background_weighted=   0.00410
# [20:18:44] DEBUG: Node survival 0.304221. Mean w=0.801963 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.347886. Mean w=0.821499 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.368327. Mean w=0.829882 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.345694. Mean w=0.780229 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.323814. Mean w=0.784446 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.369663. Mean w=0.825638 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.303677. Mean w=0.753145 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.397964. Mean w=0.828522 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.299414. Mean w=0.784993 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.305192. Mean w=0.805218 threshold=0.500000
# [20:18:45 TCNTrainer] INFO: Epoch  0 (  410/12000): potential_attractive_weighted=   0.58552, potential_repulsive_weighted=   0.62965, background_weighted=   0.00410
# [20:18:45] DEBUG: Node survival 0.395558. Mean w=0.798440 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.313458. Mean w=0.802133 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.250823. Mean w=0.769388 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.371942. Mean w=0.817085 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.308668. Mean w=0.784476 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.312324. Mean w=0.779369 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.384366. Mean w=0.808699 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.330656. Mean w=0.821933 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.400892. Mean w=0.808431 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.354713. Mean w=0.826127 threshold=0.500000
# [20:18:45 TCNTrainer] INFO: Epoch  0 (  420/12000): potential_attractive_weighted=   0.40879, potential_repulsive_weighted=   0.64260, background_weighted=   0.00410
# [20:18:45] DEBUG: Node survival 0.393297. Mean w=0.809442 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.373962. Mean w=0.823928 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.428865. Mean w=0.820204 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.318367. Mean w=0.784373 threshold=0.500000
# [20:18:45] DEBUG: Node survival 0.357626. Mean w=0.809553 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.366115. Mean w=0.829051 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.348393. Mean w=0.807406 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.285530. Mean w=0.811217 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.378764. Mean w=0.796271 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.297774. Mean w=0.795694 threshold=0.500000
# [20:18:46 TCNTrainer] INFO: Epoch  0 (  430/12000): potential_attractive_weighted=   0.39397, potential_repulsive_weighted=   0.53867, background_weighted=   0.00410
# [20:18:46] DEBUG: Node survival 0.321411. Mean w=0.782915 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.298403. Mean w=0.804809 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.321244. Mean w=0.795070 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.314927. Mean w=0.822458 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.349862. Mean w=0.795558 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.347196. Mean w=0.814860 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.361298. Mean w=0.798236 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.280813. Mean w=0.761495 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.391245. Mean w=0.815686 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.398869. Mean w=0.826897 threshold=0.500000
# [20:18:46 TCNTrainer] INFO: Epoch  0 (  440/12000): potential_attractive_weighted=   0.89881, potential_repulsive_weighted=   0.53203, background_weighted=   0.00410
# [20:18:46] DEBUG: Node survival 0.325730. Mean w=0.833436 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.320066. Mean w=0.774150 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.362174. Mean w=0.811224 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.345618. Mean w=0.819971 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.375345. Mean w=0.823084 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.359674. Mean w=0.822398 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.304080. Mean w=0.800335 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.309672. Mean w=0.774756 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.330821. Mean w=0.797098 threshold=0.500000
# [20:18:46] DEBUG: Node survival 0.408524. Mean w=0.830133 threshold=0.500000
# [20:18:46 TCNTrainer] INFO: Epoch  0 (  450/12000): potential_attractive_weighted=   0.63386, potential_repulsive_weighted=   0.46704, background_weighted=   0.00410
# [20:18:46] DEBUG: Node survival 0.368139. Mean w=0.813762 threshold=0.500000
# [20:18:47] DEBUG: Node survival 0.348028. Mean w=0.791891 threshold=0.500000
# [20:18:47] DEBUG: Node survival 0.330666. Mean w=0.809563 threshold=0.500000
# [20:18:47] DEBUG: Node survival 0.386190. Mean w=0.814739 threshold=0.500000
# ...
# [20:20:21] DEBUG: Node survival 0.368576. Mean w=0.827520 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.351773. Mean w=0.827886 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.331935. Mean w=0.795722 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.286413. Mean w=0.800073 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.326571. Mean w=0.861317 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.346840. Mean w=0.792719 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.358431. Mean w=0.804230 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.380463. Mean w=0.810945 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.305209. Mean w=0.788226 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.370671. Mean w=0.827302 threshold=0.500000
# [20:20:21 TCNTrainer] INFO: Epoch  0 ( 2840/12000): potential_attractive_weighted=   0.11136, potential_repulsive_weighted=   0.20321, background_weighted=   0.00410
# [20:20:21] DEBUG: Node survival 0.351902. Mean w=0.821997 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.312650. Mean w=0.809963 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.331190. Mean w=0.780272 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.357306. Mean w=0.808118 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.337798. Mean w=0.805798 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.313959. Mean w=0.788177 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.348739. Mean w=0.819159 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.332885. Mean w=0.802199 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.295017. Mean w=0.789081 threshold=0.500000
# [20:20:21] DEBUG: Node survival 0.274965. Mean w=0.776891 threshold=0.500000
# [20:20:22 TCNTrainer] INFO: Epoch  0 ( 2850/12000): potential_attractive_weighted=   0.25787, potential_repulsive_weighted=   0.17598, background_weighted=   0.00410
# [20:20:22] DEBUG: Node survival 0.282723. Mean w=0.821451 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.360795. Mean w=0.805553 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.260729. Mean w=0.811145 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.314335. Mean w=0.798424 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.352810. Mean w=0.762347 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.355747. Mean w=0.784807 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.305000. Mean w=0.791035 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.258065. Mean w=0.790604 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.362560. Mean w=0.817769 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.447598. Mean w=0.816002 threshold=0.500000
# [20:20:22 TCNTrainer] INFO: Epoch  0 ( 2860/12000): potential_attractive_weighted=   0.07827, potential_repulsive_weighted=   0.28289, background_weighted=   0.00410
# [20:20:22] DEBUG: Node survival 0.400199. Mean w=0.809623 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.375332. Mean w=0.792470 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.393315. Mean w=0.835699 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.362409. Mean w=0.801869 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.334732. Mean w=0.826427 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.292608. Mean w=0.794528 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.353545. Mean w=0.774594 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.343009. Mean w=0.812498 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.289346. Mean w=0.769312 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.375873. Mean w=0.802678 threshold=0.500000
# [20:20:22 TCNTrainer] INFO: Epoch  0 ( 2870/12000): potential_attractive_weighted=   0.13994, potential_repulsive_weighted=   0.22399, background_weighted=   0.00410
# [20:20:22] DEBUG: Node survival 0.322198. Mean w=0.808440 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.402275. Mean w=0.833949 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.385439. Mean w=0.793749 threshold=0.500000
# [20:20:22] DEBUG: Node survival 0.367796. Mean w=0.818669 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.394012. Mean w=0.836153 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.330097. Mean w=0.781212 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.347274. Mean w=0.785295 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.270671. Mean w=0.821110 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.388866. Mean w=0.826683 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.339942. Mean w=0.823191 threshold=0.500000
# [20:20:23 TCNTrainer] INFO: Epoch  0 ( 2880/12000): potential_attractive_weighted=   0.08109, potential_repulsive_weighted=   0.13634, background_weighted=   0.00410
# [20:20:23] DEBUG: Node survival 0.332815. Mean w=0.799241 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.367174. Mean w=0.815547 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.302028. Mean w=0.806985 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.346908. Mean w=0.813714 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.365400. Mean w=0.802418 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.320330. Mean w=0.826262 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.308236. Mean w=0.792149 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.379773. Mean w=0.805021 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.318663. Mean w=0.775795 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.308741. Mean w=0.785443 threshold=0.500000
# [20:20:23 TCNTrainer] INFO: Epoch  0 ( 2890/12000): potential_attractive_weighted=   0.08431, potential_repulsive_weighted=   0.21024, background_weighted=   0.00410
# [20:20:23] DEBUG: Node survival 0.283638. Mean w=0.807304 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.311935. Mean w=0.808545 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.326923. Mean w=0.828185 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.385321. Mean w=0.812195 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.308901. Mean w=0.781824 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.329670. Mean w=0.780400 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.292517. Mean w=0.780620 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.386087. Mean w=0.800121 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.366812. Mean w=0.815024 threshold=0.500000
# [20:20:23] DEBUG: Node survival 0.315645. Mean w=0.825337 threshold=0.500000
# [20:20:23 TCNTrainer] INFO: Epoch  0 ( 2900/12000): potential_attractive_weighted=   0.10685, potential_repulsive_weighted=   0.15583, background_weighted=   0.00410
# [20:20:24] DEBUG: Node survival 0.307919. Mean w=0.747278 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.399812. Mean w=0.835187 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.287248. Mean w=0.769070 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.365402. Mean w=0.821466 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.398852. Mean w=0.823501 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.322071. Mean w=0.793999 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.322186. Mean w=0.803768 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.365179. Mean w=0.812450 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.354359. Mean w=0.821742 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.382530. Mean w=0.822701 threshold=0.500000
# [20:20:24 TCNTrainer] INFO: Epoch  0 ( 2910/12000): potential_attractive_weighted=   0.08147, potential_repulsive_weighted=   0.17483, background_weighted=   0.00410
# [20:20:24] DEBUG: Node survival 0.398557. Mean w=0.814356 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.299959. Mean w=0.795004 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.361535. Mean w=0.801448 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.339493. Mean w=0.808609 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.350289. Mean w=0.809254 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.312798. Mean w=0.803318 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.273689. Mean w=0.760475 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.376968. Mean w=0.801866 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.313405. Mean w=0.768749 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.372572. Mean w=0.791182 threshold=0.500000
# [20:20:24 TCNTrainer] INFO: Epoch  0 ( 2920/12000): potential_attractive_weighted=   0.31105, potential_repulsive_weighted=   0.13307, background_weighted=   0.00410
# [20:20:24] DEBUG: Node survival 0.424520. Mean w=0.822260 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.328225. Mean w=0.788474 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.342900. Mean w=0.825470 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.263158. Mean w=0.781780 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.341139. Mean w=0.818569 threshold=0.500000
# [20:20:24] DEBUG: Node survival 0.359691. Mean w=0.813303 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.312027. Mean w=0.816888 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.348107. Mean w=0.837688 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.387415. Mean w=0.813144 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.381939. Mean w=0.815450 threshold=0.500000
# [20:20:25 TCNTrainer] INFO: Epoch  0 ( 2930/12000): potential_attractive_weighted=   0.08133, potential_repulsive_weighted=   0.27377, background_weighted=   0.00410
# [20:20:25] DEBUG: Node survival 0.374238. Mean w=0.817721 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.358227. Mean w=0.813056 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.335692. Mean w=0.813836 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.248164. Mean w=0.735675 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.355725. Mean w=0.796123 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.304598. Mean w=0.806246 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.296414. Mean w=0.798280 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.312434. Mean w=0.793019 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.285847. Mean w=0.788994 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.295863. Mean w=0.773295 threshold=0.500000
# [20:20:25 TCNTrainer] INFO: Epoch  0 ( 2940/12000): potential_attractive_weighted=   0.04589, potential_repulsive_weighted=   0.25498, background_weighted=   0.00410
# [20:20:25] DEBUG: Node survival 0.348563. Mean w=0.794114 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.292925. Mean w=0.803869 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.260358. Mean w=0.801326 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.356822. Mean w=0.815962 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.345051. Mean w=0.817492 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.280880. Mean w=0.805209 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.322655. Mean w=0.791713 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.353479. Mean w=0.813890 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.353771. Mean w=0.801112 threshold=0.500000
# [20:20:25] DEBUG: Node survival 0.275510. Mean w=0.772284 threshold=0.500000
# [20:20:25 TCNTrainer] INFO: Epoch  0 ( 2950/12000): potential_attractive_weighted=   0.16464, potential_repulsive_weighted=   0.23323, background_weighted=   0.00410
# [20:20:26] DEBUG: Node survival 0.350041. Mean w=0.779034 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.280718. Mean w=0.774902 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.362793. Mean w=0.799349 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.321535. Mean w=0.798334 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.351630. Mean w=0.794901 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.295388. Mean w=0.808319 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.307087. Mean w=0.801637 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.383140. Mean w=0.833699 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.395158. Mean w=0.797099 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.333036. Mean w=0.798939 threshold=0.500000
# [20:20:26 TCNTrainer] INFO: Epoch  0 ( 2960/12000): potential_attractive_weighted=   0.05110, potential_repulsive_weighted=   0.21019, background_weighted=   0.00410
# [20:20:26] DEBUG: Node survival 0.350836. Mean w=0.815522 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.318086. Mean w=0.817143 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.301645. Mean w=0.810813 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.334881. Mean w=0.807224 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.353147. Mean w=0.809979 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.297231. Mean w=0.797401 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.383240. Mean w=0.812300 threshold=0.500000
# [20:20:26] DEBUG: Node survival 0.344444. Mean w=0.834901 threshold=0.500000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 3
#       1 import os
#       2 os.environ["PYTORCH_NVFUSER_DISABLE"] = ""
# ----> 3 trainer.train_step()
#
# File ~/Documents/23/git_sync/gnn_tracking/src/gnn_tracking/training/tcn_trainer.py:329, in TCNTrainer.train_step(self, max_batches)
#     327 try:
#     328     data = data.to(self.device)
# --> 329     model_output = self.evaluate_model(data)
#     330     batch_loss, batch_losses, loss_weights = self.get_batch_losses(
#     331         model_output
#     332     )
#     333     self.optimizer.zero_grad(set_to_none=True)
#
# File ~/Documents/23/git_sync/gnn_tracking/src/gnn_tracking/training/tcn_trainer.py:183, in TCNTrainer.evaluate_model(self, data, mask_pids_reco)
#     175 """Evaluate the model on the data and return a dictionary of outputs
#     176
#     177 Args:
#     178     data:
#     179     mask_pids_reco: If True, mask out PIDs for non-reconstructables
#     180 """
#     181 data = data.to(self.device)
# --> 183 out = self.model(data)
#     185 if mask_pids_reco:
#     186     pid_field = data.particle_id * data.reconstructable.long()
#
# File /scratch/gpfs/kl5675/micromamba/envs/gnn/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[103], line 209, in PreTrainedECGraphTCN.forward(self, data)
#     205 def forward(
#     206     self,
#     207     data: Data,
#     208 ) -> dict[str, Tensor]:
# --> 209     return self._gtcn.forward(data=data)
#
# Cell In[103], line 107, in ModularGraphTCN.forward(self, data)
#     104 # ew = data.edge_weights.detach().squeeze()
#     105 # ew = (ew - ew.mean()) / ew.std()
#     106 edge_mask = data.edge_weights.squeeze() > self.threshold
# --> 107 data = edge_subgraph(data, edge_mask)
#     109 if self._mask_orphan_nodes:
#     110     connected_nodes = data.edge_index.flatten().unique()
#
# File ~/Documents/23/git_sync/gnn_tracking/src/gnn_tracking/utils/graph_masks.py:62, in edge_subgraph(data, subset)
#      60 cat_dim = data.__cat_dim__(key, value)
#      61 if subset.dtype == torch.bool:
# ---> 62     new_data[key] = mask_select(value, cat_dim, subset)
#      63 else:
#      64     new_data[key] = value.index_select(cat_dim, subset)
#
# File ~/Documents/23/git_sync/gnn_tracking/src/gnn_tracking/utils/graph_masks.py:35, in mask_select(src, dim, mask)
#      32 size = [1] * src.dim()
#      33 size[dim] = mask.numel()
# ---> 35 out = src.masked_select(mask.view(size))
#      37 size = list(src.size())
#      38 size[dim] = -1
#
# KeyboardInterrupt:

# %%
# id(trainer.model._gtcn.threshold) in [id(x) for x in trainer.model.parameters()]
# Out:
# True

# %%
trainer.model._gtcn.threshold.data
# Out:
# tensor(0.5000, device='cuda:0')

# %%
set(trainer.model._gtcn.ec.parameters()).issubset(set(trainer.model.parameters()))
# Out:
# True
