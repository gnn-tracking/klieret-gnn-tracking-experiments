# %%
from gnn_tracking_hpo.util.paths import find_checkpoints, add_scripts_path

add_scripts_path()

# %%
from gnn_tracking_hpo.util.paths import get_config

checkpoint_path = find_checkpoints("ec-s9", "009d")[-1]
config = get_config("ec-s9", "009d")

# %%
config.update({"n_graphs_train": 1, "n_graphs_val": 100, "n_graphs_test": 1})

# %%
from tune_ec_sectorized import ECTrainable

# %%
trainable = ECTrainable(config)
# Out:
# DEBUG: Got config
# {'batch_size': 1,
#  'focal_alpha': 0.7397820322968228,
#  'focal_gamma': 4,
#  'gnn_tracking_experiments_hash': '1c4385064cb8472d7070c92d38d2958ab96e7485',
#  'gnn_tracking_hash': 'd1903e7319ef1dc27f2632d27212ce802d1273e2',
#  'lr': 0.00010008424753725798,
#  'lw_edge': 1.0,
#  'm_L_ec': 7,
#  'm_alpha_ec': 0.5082980468439962,
#  'm_e_dim': 4,
#  'm_h_dim': 5,
#  'm_hidden_dim': 118,
#  'm_interaction_edge_hidden_dim': 85,
#  'm_interaction_node_hidden_dim': 94,
#  'n_graphs_test': 1,
#  'n_graphs_train': 1,
#  'n_graphs_val': 100,
#  'optimizer': 'adam',
#  'scheduler': None,
#  'sector': 9,
#  'test': False,
#  'training_pt_thld': 0.0,
#  'training_without_noise': False,
#  'training_without_non_reconstructable': False}
# INFO: Loading data to cpu memory
# INFO: Loading 102 graphs (out of 371 available).
# DEBUG: Parameters for data loaders: {'batch_size': 1, 'num_workers': 12}
# INFO: Using device cpu

# %%
ec = trainable.trainer.model

# %%
from torch_geometric.data import Data
from torch import Tensor
from torch import nn
import torch

class TrainableThldEC(nn.Module):
    def __init__(self, ec: nn.Module):
        """Edge classifier with a trainable threshold based on an existing
        classifier. If the parameters of the existing classifier are fixed, the
        threshold is the only trainable parameter.

        Args:
            ec: Edge classifier
        """
        super().__init__()
        self.ec = ec
        #: The threshold to use for the edge classifier
        self.threshold = nn.parameter.Parameter(torch.tensor(0.5), requires_grad=True)

    def _evaluate_ec(self, data) -> Tensor:
        r = self.ec(data)
        if isinstance(r, dict):
            return r["W"]
        else:
            return r

    def forward(self, data: Data) -> Tensor:
        return self._evaluate_ec(data) > self.threshold  # type: ignore

# %%
for param in ec.parameters():
    param.requires_grad = False

# %%
ttec = TrainableThldEC(ec)

# %%
from gnn_tracking.models.track_condensation_networks import ModularGraphTCN
from gnn_tracking.models.resin import ResIN


class PreTrainedECGraphTCN(nn.Module):
    def __init__(
        self,
        ec,
        *,
        node_indim: int,
        edge_indim: int,
        interaction_node_hidden_dim=5,
        interaction_edge_hidden_dim=4,
        h_dim=5,
        e_dim=4,
        h_outdim=2,
        hidden_dim=40,
        L_hc=3,
        alpha_hc: float = 0.5,
    ):
        """
        """
        super().__init__()
        hc_in = ResIN.identical_in_layers(
            node_indim=h_dim,
            edge_indim=e_dim,
            node_hidden_dim=interaction_node_hidden_dim,
            edge_hidden_dim=interaction_edge_hidden_dim,
            node_outdim=h_dim,
            edge_outdim=e_dim,
            object_hidden_dim=hidden_dim,
            relational_hidden_dim=hidden_dim,
            alpha=alpha_hc,
            n_layers=L_hc,
        )
        self._gtcn = ModularGraphTCN(
            ec=ec,
            hc_in=hc_in,
            node_indim=node_indim,
            edge_indim=edge_indim,
            h_dim=h_dim,
            e_dim=e_dim,
            h_outdim=h_outdim,
            hidden_dim=hidden_dim,
            L_hc=L_hc,
            feed_edge_weights=False,
        )

    def forward(
        self,
        data: Data,
    ) -> dict[str, Tensor]:
        return self._gtcn.forward(data=data)

# %%
from gnn_tracking.utils.dictionaries import subdict_with_prefix_stripped
from typing import Any
from gnn_tracking_hpo.trainable import TCNTrainable


class PretrainedECTrainable(TCNTrainable):
    def get_loss_functions(self) -> dict[str, Any]:
        return {
            "potential": self.get_potential_loss_function(),
            "background": self.get_background_loss_function(),
        }

    def get_model(self) -> nn.Module:
        # todo: add config for ec
        return PreTrainedECGraphTCN(ttec,
            node_indim=6, edge_indim=4, **subdict_with_prefix_stripped(self.tc, "m_")
        )

# %%
from gnn_tracking_hpo.trainable import suggest_default_values
from gnn_tracking_hpo.config import get_metadata

config = {
    "lr": 0.0005655795153563859,
    "sb": 0.12120230680126508,
    "q_min": 0.3611768519294592,
    "m_L_hc": 3,
    "sector": 9,
    "m_e_dim": 5,
    "m_h_dim": 7,
    "optimizer": "adam",
    "scheduler": None,
    "batch_size": 1,
    "m_alpha_hc": .9,
    "m_h_outdim": 2,
    "attr_pt_thld": 0.5654455552047115,
    "m_hidden_dim": 116,
    "n_graphs_val": 69,
    "n_graphs_test": 1,
    "n_graphs_train": 300,
    "training_pt_thld": 0.9,
    "training_without_noise": True,
    "lw_potential_repulsive": 1e1,
    "lw_potential_attractive": 1e6,
    "lw_potential_background": 1e-2,
    "m_interaction_node_hidden_dim": 64,
    "m_interaction_edge_hidden_dim": 64,
    "repulsive_radius_threshold": 2.,
}
config.update(get_metadata())
suggest_default_values(config, None, perfect_ec=True)
del config["m_ec_tpr"]
del config["m_ec_tnr"]
# Out:
# WARNING: Repository is dirty, commit hash may not be accurate.

# %%
pt = PretrainedECTrainable(config)
# Out:
# DEBUG: Got config
# {'attr_pt_thld': 0.5654455552047115,
#  'batch_size': 1,
#  'gnn_tracking_experiments_hash': '1c4385064cb8472d7070c92d38d2958ab96e7485',
#  'gnn_tracking_hash': 'd1903e7319ef1dc27f2632d27212ce802d1273e2',
#  'lr': 0.0005655795153563859,
#  'lw_potential_attractive': 1000000.0,
#  'lw_potential_background': 0.01,
#  'lw_potential_repulsive': 10.0,
#  'm_L_hc': 3,
#  'm_alpha_hc': 0.9,
#  'm_e_dim': 5,
#  'm_h_dim': 7,
#  'm_h_outdim': 2,
#  'm_hidden_dim': 116,
#  'm_interaction_edge_hidden_dim': 64,
#  'm_interaction_node_hidden_dim': 64,
#  'n_graphs_test': 1,
#  'n_graphs_train': 300,
#  'n_graphs_val': 69,
#  'optimizer': 'adam',
#  'q_min': 0.3611768519294592,
#  'repulsive_radius_threshold': 2.0,
#  'sb': 0.12120230680126508,
#  'scheduler': None,
#  'sector': 9,
#  'test': False,
#  'training_pt_thld': 0.9,
#  'training_without_noise': True,
#  'training_without_non_reconstructable': False}
# INFO: Loading data to cpu memory
# INFO: Loading 370 graphs (out of 371 available).
# DEBUG: Parameters for data loaders: {'batch_size': 1, 'num_workers': 12}
# INFO: Using device cpu

# %%
for i in range(2):
    pt.step()
# Out:
# INFO: Epoch  1 (    0/300): background_weighted=   0.56950, potential_attractive_weighted=   0.79266, potential_repulsive_weighted= 629.81876
# INFO: Epoch  1 (   10/300): background_weighted=   0.63192, potential_attractive_weighted=   0.05775, potential_repulsive_weighted= 400.27641
# INFO: Epoch  1 (   20/300): background_weighted=   0.69248, potential_attractive_weighted=   0.28210, potential_repulsive_weighted= 391.10447
# INFO: Epoch  1 (   30/300): background_weighted=   0.77643, potential_attractive_weighted=   3.33007, potential_repulsive_weighted= 163.50866
# INFO: Epoch  1 (   40/300): background_weighted=   0.88735, potential_attractive_weighted=   9.87966, potential_repulsive_weighted= 160.21511
# INFO: Epoch  1 (   50/300): background_weighted=   0.95290, potential_attractive_weighted=   4.37769, potential_repulsive_weighted= 173.75721
# INFO: Epoch  1 (   60/300): background_weighted=   0.96772, potential_attractive_weighted=   1.84598, potential_repulsive_weighted= 136.11625
# INFO: Epoch  1 (   70/300): background_weighted=   0.97385, potential_attractive_weighted=   0.77254, potential_repulsive_weighted= 159.48027
# INFO: Epoch  1 (   80/300): background_weighted=   0.97897, potential_attractive_weighted=   0.39601, potential_repulsive_weighted= 190.76674
# INFO: Epoch  1 (   90/300): background_weighted=   0.98331, potential_attractive_weighted=   0.16660, potential_repulsive_weighted= 198.45840
# INFO: Epoch  1 (  100/300): background_weighted=   0.98934, potential_attractive_weighted=   0.40141, potential_repulsive_weighted= 166.97048
# INFO: Epoch  1 (  110/300): background_weighted=   0.98865, potential_attractive_weighted=   4.23983, potential_repulsive_weighted= 171.92867
# INFO: Epoch  1 (  120/300): background_weighted=   0.97415, potential_attractive_weighted=   6.75043, potential_repulsive_weighted= 114.89754
# INFO: Epoch  1 (  130/300): background_weighted=   0.96626, potential_attractive_weighted=   0.32120, potential_repulsive_weighted= 123.34872
# INFO: Epoch  1 (  140/300): background_weighted=   0.97041, potential_attractive_weighted=   0.06891, potential_repulsive_weighted= 212.19353
# INFO: Epoch  1 (  150/300): background_weighted=   0.97900, potential_attractive_weighted=   0.16656, potential_repulsive_weighted= 175.22011
# INFO: Epoch  1 (  160/300): background_weighted=   0.98275, potential_attractive_weighted=   0.27989, potential_repulsive_weighted= 141.04949
# INFO: Epoch  1 (  170/300): background_weighted=   0.98695, potential_attractive_weighted=   0.15150, potential_repulsive_weighted= 138.32041
# INFO: Epoch  1 (  180/300): background_weighted=   0.98997, potential_attractive_weighted=   0.06459, potential_repulsive_weighted= 177.46479
# INFO: Epoch  1 (  190/300): background_weighted=   0.99125, potential_attractive_weighted=   0.02478, potential_repulsive_weighted= 185.33686
# INFO: Epoch  1 (  200/300): background_weighted=   0.99060, potential_attractive_weighted=   0.01212, potential_repulsive_weighted= 133.08576
# INFO: Epoch  1 (  210/300): background_weighted=   0.99357, potential_attractive_weighted=   0.01397, potential_repulsive_weighted= 135.70300
# INFO: Epoch  1 (  220/300): background_weighted=   0.99320, potential_attractive_weighted=   0.01850, potential_repulsive_weighted= 133.13612
# INFO: Epoch  1 (  230/300): background_weighted=   0.99434, potential_attractive_weighted=   0.02804, potential_repulsive_weighted= 156.50035
# INFO: Epoch  1 (  240/300): background_weighted=   0.99441, potential_attractive_weighted=   0.01474, potential_repulsive_weighted= 114.84467
# INFO: Epoch  1 (  250/300): background_weighted=   0.99515, potential_attractive_weighted=   0.04983, potential_repulsive_weighted= 140.87437
# INFO: Epoch  1 (  260/300): background_weighted=   0.99557, potential_attractive_weighted=   0.02323, potential_repulsive_weighted= 133.00159
# INFO: Epoch  1 (  270/300): background_weighted=   0.99557, potential_attractive_weighted=   0.02285, potential_repulsive_weighted= 182.50561
# INFO: Epoch  1 (  280/300): background_weighted=   0.99631, potential_attractive_weighted=   0.02055, potential_repulsive_weighted= 153.82262
# INFO: Epoch  1 (  290/300): background_weighted=   0.99566, potential_attractive_weighted=   0.03015, potential_repulsive_weighted= 119.93099
# INFO: Training for epoch 1 took 23.42 seconds
# INFO: Starting hyperparameter scan for clustering
# INFO: Completed 12 trials, pruned 0 trials
# DEBUG: Evaluating all metrics for best clustering
# INFO: Evaluating all metrics took 2.79 seconds
# INFO: Clustering hyperparameter scan & metric evaluation took 31.39 seconds
# DEBUG: Starting from params: {'eps': 0.9854345081948057, 'min_samples': 1}
# INFO: Starting hyperparameter scan for clustering
# INFO: Completed 12 trials, pruned 0 trials
# DEBUG: Evaluating all metrics for best clustering
# INFO: Evaluating all metrics took 1.53 seconds
# INFO: Clustering hyperparameter scan & metric evaluation took 19.51 seconds
# INFO: Test step for epoch 1 took 89.63 seconds
# INFO: Results 1:
# +-----+-------------------------------------+------------+
# |     | Metric                              |      Value |
# +=====+=====================================+============+
# |     | FNR_pt0.9                           |    1.00000 |
# |     | FNR_pt1.5                           |    1.00000 |
# |     | FPR_pt0.9                           |    0.00000 |
# |     | FPR_pt1.5                           |    0.00000 |
# |     | TNR_pt0.9                           |    1.00000 |
# |     | TNR_pt1.5                           |    1.00000 |
# | --> | TPR_pt0.9                           |    0.00000 |
# | --> | TPR_pt1.5                           |    0.00000 |
# |     | acc_pt0.9                           |    0.97879 |
# |     | acc_pt1.5                           |    0.97904 |
# |     | adjusted_mutual_info                |    0.00000 |
# |     | adjusted_rand                       |    0.00000 |
# |     | background                          |    0.99740 |
# |     | background_train                    |    0.94627 |
# |     | background_weighted                 |    0.99740 |
# |     | background_weighted_train           |    0.94627 |
# |     | best_dbscan_eps                     |    0.98543 |
# |     | best_dbscan_min_samples             |    1.00000 |
# |     | completeness                        |    1.00000 |
# |     | fowlkes_mallows                     |    0.07140 |
# |     | homogeneity                         |    0.00000 |
# |     | potential_attractive                |    0.00000 |
# |     | potential_attractive_train          |    0.00000 |
# |     | potential_attractive_weighted       |    0.03310 |
# |     | potential_attractive_weighted_train |    0.97124 |
# |     | potential_repulsive                 |  118.91246 |
# |     | potential_repulsive_train           |   17.43909 |
# |     | potential_repulsive_weighted        | 1189.12458 |
# |     | potential_repulsive_weighted_train  |  174.39089 |
# |     | roc_auc_10FPR_pt0.9                 |    0.50000 |
# |     | roc_auc_10FPR_pt1.5                 |    0.50000 |
# |     | roc_auc_20FPR_pt0.9                 |    0.50000 |
# |     | roc_auc_20FPR_pt1.5                 |    0.50000 |
# |     | roc_auc_5FPR_pt0.9                  |    0.50000 |
# |     | roc_auc_5FPR_pt1.5                  |    0.50000 |
# |     | roc_auc_pt0.9                       |    0.50000 |
# |     | roc_auc_pt1.5                       |    0.50000 |
# |     | tc_FNR_pt0.9                        |    1.00000 |
# |     | tc_FNR_pt1.5                        |    1.00000 |
# |     | tc_FPR_pt0.9                        |    0.00000 |
# |     | tc_FPR_pt1.5                        |    0.00000 |
# |     | tc_TNR_pt0.9                        |    1.00000 |
# |     | tc_TNR_pt1.5                        |    1.00000 |
# | --> | tc_TPR_pt0.9                        |    0.00000 |
# | --> | tc_TPR_pt1.5                        |    0.00000 |
# |     | tc_acc_pt0.9                        |    0.81821 |
# |     | tc_acc_pt1.5                        |    0.87737 |
# |     | tc_adjusted_mutual_info             |    0.00000 |
# |     | tc_adjusted_rand                    |    0.00000 |
# |     | tc_background                       |    0.99642 |
# |     | tc_background_weighted              |    0.99642 |
# |     | tc_best_dbscan_eps                  |    0.97105 |
# |     | tc_best_dbscan_min_samples          |    1.00000 |
# |     | tc_completeness                     |    1.00000 |
# |     | tc_fowlkes_mallows                  |    0.16070 |
# |     | tc_homogeneity                      |    0.00000 |
# |     | tc_potential_attractive             |    0.00000 |
# |     | tc_potential_attractive_weighted    |    0.03457 |
# |     | tc_potential_repulsive              |   16.41443 |
# |     | tc_potential_repulsive_weighted     |  164.14429 |
# |     | tc_roc_auc_10FPR_pt0.9              |    0.50000 |
# |     | tc_roc_auc_10FPR_pt1.5              |    0.50000 |
# |     | tc_roc_auc_20FPR_pt0.9              |    0.50000 |
# |     | tc_roc_auc_20FPR_pt1.5              |    0.50000 |
# |     | tc_roc_auc_5FPR_pt0.9               |    0.50000 |
# |     | tc_roc_auc_5FPR_pt1.5               |    0.50000 |
# |     | tc_roc_auc_pt0.9                    |    0.50000 |
# |     | tc_roc_auc_pt1.5                    |    0.50000 |
# |     | tc_total                            |  165.17528 |
# | --> | tc_trk.double_majority              |    0.00000 |
# | --> | tc_trk.double_majority_pt0.5        |    0.00000 |
# | --> | tc_trk.double_majority_pt0.9        |    0.00000 |
# | --> | tc_trk.double_majority_pt1.5        |    0.00000 |
# | --> | tc_trk.fake_double_majority         |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt0.5   |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt0.9   |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt1.5   |    0.02421 |
# |     | tc_trk.fake_lhc                     |    1.00000 |
# |     | tc_trk.fake_lhc_pt0.5               |    1.00000 |
# |     | tc_trk.fake_lhc_pt0.9               |    1.00000 |
# |     | tc_trk.fake_lhc_pt1.5               |    1.00000 |
# |     | tc_trk.fake_perfect                 |    0.02353 |
# |     | tc_trk.fake_perfect_pt0.5           |    0.02353 |
# |     | tc_trk.fake_perfect_pt0.9           |    0.02353 |
# |     | tc_trk.fake_perfect_pt1.5           |    0.02421 |
# |     | tc_trk.lhc                          |    0.00000 |
# |     | tc_trk.lhc_pt0.5                    |    0.00000 |
# |     | tc_trk.lhc_pt0.9                    |    0.00000 |
# |     | tc_trk.lhc_pt1.5                    |    0.00000 |
# |     | tc_trk.n_cleaned_clusters           |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt0.5     |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt0.9     |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt1.5     |    0.39130 |
# |     | tc_trk.n_particles                  |   44.68116 |
# |     | tc_trk.n_particles_pt0.5            |   44.68116 |
# |     | tc_trk.n_particles_pt0.9            |   44.68116 |
# |     | tc_trk.n_particles_pt1.5            |   16.37681 |
# |     | tc_trk.perfect                      |    0.00000 |
# |     | tc_trk.perfect_pt0.5                |    0.00000 |
# |     | tc_trk.perfect_pt0.9                |    0.00000 |
# |     | tc_trk.perfect_pt1.5                |    0.00000 |
# |     | tc_v_measure                        |    0.00000 |
# |     | total                               | 1190.15508 |
# |     | total_train                         |  176.30840 |
# | --> | trk.double_majority                 |    0.00000 |
# | --> | trk.double_majority_pt0.5           |    0.00000 |
# | --> | trk.double_majority_pt0.9           |    0.00000 |
# | --> | trk.double_majority_pt1.5           |    0.00000 |
# | --> | trk.fake_double_majority            |    0.00434 |
# | --> | trk.fake_double_majority_pt0.5      |    0.00227 |
# | --> | trk.fake_double_majority_pt0.9      |    0.00144 |
# | --> | trk.fake_double_majority_pt1.5      |    0.00230 |
# |     | trk.fake_lhc                        |    1.00000 |
# |     | trk.fake_lhc_pt0.5                  |    1.00000 |
# |     | trk.fake_lhc_pt0.9                  |    1.00000 |
# |     | trk.fake_lhc_pt1.5                  |    1.00000 |
# |     | trk.fake_perfect                    |    0.00434 |
# |     | trk.fake_perfect_pt0.5              |    0.00227 |
# |     | trk.fake_perfect_pt0.9              |    0.00144 |
# |     | trk.fake_perfect_pt1.5              |    0.00230 |
# |     | trk.lhc                             |    0.00000 |
# |     | trk.lhc_pt0.5                       |    0.00000 |
# |     | trk.lhc_pt0.9                       |    0.00000 |
# |     | trk.lhc_pt1.5                       |    0.00000 |
# |     | trk.n_cleaned_clusters              |    1.00000 |
# |     | trk.n_cleaned_clusters_pt0.5        |    0.23188 |
# |     | trk.n_cleaned_clusters_pt0.9        |    0.07246 |
# |     | trk.n_cleaned_clusters_pt1.5        |    0.04348 |
# |     | trk.n_particles                     |  235.69565 |
# |     | trk.n_particles_pt0.5               |  107.79710 |
# |     | trk.n_particles_pt0.9               |   44.68116 |
# |     | trk.n_particles_pt1.5               |   16.37681 |
# |     | trk.perfect                         |    0.00000 |
# |     | trk.perfect_pt0.5                   |    0.00000 |
# |     | trk.perfect_pt0.9                   |    0.00000 |
# |     | trk.perfect_pt1.5                   |    0.00000 |
# |     | v_measure                           |    0.00000 |
# +-----+-------------------------------------+------------+
# INFO: Epoch  2 (    0/300): background_weighted=   0.99687, potential_attractive_weighted=   0.03464, potential_repulsive_weighted= 153.78353
# INFO: Epoch  2 (   10/300): background_weighted=   0.99586, potential_attractive_weighted=   0.03425, potential_repulsive_weighted= 132.93465
# INFO: Epoch  2 (   20/300): background_weighted=   0.99695, potential_attractive_weighted=   0.17156, potential_repulsive_weighted= 208.39893
# INFO: Epoch  2 (   30/300): background_weighted=   0.99616, potential_attractive_weighted=   0.11662, potential_repulsive_weighted= 127.67500
# INFO: Epoch  2 (   40/300): background_weighted=   0.99711, potential_attractive_weighted=   0.13591, potential_repulsive_weighted= 143.20074
# INFO: Epoch  2 (   50/300): background_weighted=   0.99715, potential_attractive_weighted=   0.11687, potential_repulsive_weighted= 143.10902
# INFO: Epoch  2 (   60/300): background_weighted=   0.99725, potential_attractive_weighted=   0.34766, potential_repulsive_weighted= 150.76849
# INFO: Epoch  2 (   70/300): background_weighted=   0.99683, potential_attractive_weighted=   0.56667, potential_repulsive_weighted= 147.99141
# INFO: Epoch  2 (   80/300): background_weighted=   0.99716, potential_attractive_weighted=   0.33616, potential_repulsive_weighted= 171.17065
# INFO: Epoch  2 (   90/300): background_weighted=   0.99739, potential_attractive_weighted=   0.61246, potential_repulsive_weighted= 142.54214
# INFO: Epoch  2 (  100/300): background_weighted=   0.99701, potential_attractive_weighted=   1.10814, potential_repulsive_weighted= 108.79182
# INFO: Epoch  2 (  110/300): background_weighted=   0.99755, potential_attractive_weighted=   0.71074, potential_repulsive_weighted= 121.47767
# INFO: Epoch  2 (  120/300): background_weighted=   0.99773, potential_attractive_weighted=   0.48866, potential_repulsive_weighted= 175.52048
# INFO: Epoch  2 (  130/300): background_weighted=   0.99733, potential_attractive_weighted=   1.79163, potential_repulsive_weighted= 147.17045
# INFO: Epoch  2 (  140/300): background_weighted=   0.99816, potential_attractive_weighted=   1.47762, potential_repulsive_weighted= 154.79862
# INFO: Epoch  2 (  150/300): background_weighted=   0.99682, potential_attractive_weighted=   1.09943, potential_repulsive_weighted= 141.67676
# INFO: Epoch  2 (  160/300): background_weighted=   0.99596, potential_attractive_weighted=   3.41579, potential_repulsive_weighted= 159.72973
# INFO: Epoch  2 (  170/300): background_weighted=   0.99586, potential_attractive_weighted=   2.71819, potential_repulsive_weighted= 167.37213
# INFO: Epoch  2 (  180/300): background_weighted=   0.99405, potential_attractive_weighted=   0.74512, potential_repulsive_weighted= 131.51943
# INFO: Epoch  2 (  190/300): background_weighted=   0.99487, potential_attractive_weighted=   0.79585, potential_repulsive_weighted= 164.75574
# INFO: Epoch  2 (  200/300): background_weighted=   0.99550, potential_attractive_weighted=   1.27800, potential_repulsive_weighted=  89.89524
# INFO: Epoch  2 (  210/300): background_weighted=   0.99638, potential_attractive_weighted=   0.87902, potential_repulsive_weighted= 138.98325
# INFO: Epoch  2 (  220/300): background_weighted=   0.99675, potential_attractive_weighted=   1.01881, potential_repulsive_weighted= 102.31701
# INFO: Epoch  2 (  230/300): background_weighted=   0.99780, potential_attractive_weighted=   1.56482, potential_repulsive_weighted= 209.93790
# INFO: Epoch  2 (  240/300): background_weighted=   0.99657, potential_attractive_weighted=   1.12823, potential_repulsive_weighted= 177.20243
# INFO: Epoch  2 (  250/300): background_weighted=   0.99673, potential_attractive_weighted=   0.95258, potential_repulsive_weighted= 169.86912
# INFO: Epoch  2 (  260/300): background_weighted=   0.99680, potential_attractive_weighted=   1.30735, potential_repulsive_weighted= 154.15901
# INFO: Epoch  2 (  270/300): background_weighted=   0.99707, potential_attractive_weighted=   2.17111, potential_repulsive_weighted= 179.98432
# INFO: Epoch  2 (  280/300): background_weighted=   0.99745, potential_attractive_weighted=   1.46874, potential_repulsive_weighted= 163.61616
# INFO: Epoch  2 (  290/300): background_weighted=   0.99659, potential_attractive_weighted=   1.58825, potential_repulsive_weighted= 167.13634
# INFO: Training for epoch 2 took 23.18 seconds
# DEBUG: Starting from params: {'eps': 0.9710542559357909, 'min_samples': 1}
# INFO: Starting hyperparameter scan for clustering
# INFO: Completed 12 trials, pruned 0 trials
# DEBUG: Evaluating all metrics for best clustering
# INFO: Evaluating all metrics took 2.77 seconds
# INFO: Clustering hyperparameter scan & metric evaluation took 31.70 seconds
# DEBUG: Starting from params: {'eps': 0.9761934919750893, 'min_samples': 1}
# INFO: Starting hyperparameter scan for clustering
# INFO: Completed 12 trials, pruned 0 trials
# DEBUG: Evaluating all metrics for best clustering
# INFO: Evaluating all metrics took 1.53 seconds
# INFO: Clustering hyperparameter scan & metric evaluation took 19.56 seconds
# INFO: Test step for epoch 2 took 90.15 seconds
# INFO: Results 2:
# +-----+-------------------------------------+------------+
# |     | Metric                              |      Value |
# +=====+=====================================+============+
# |     | FNR_pt0.9                           |    1.00000 |
# |     | FNR_pt1.5                           |    1.00000 |
# |     | FPR_pt0.9                           |    0.00000 |
# |     | FPR_pt1.5                           |    0.00000 |
# |     | TNR_pt0.9                           |    1.00000 |
# |     | TNR_pt1.5                           |    1.00000 |
# | --> | TPR_pt0.9                           |    0.00000 |
# | --> | TPR_pt1.5                           |    0.00000 |
# |     | acc_pt0.9                           |    0.97879 |
# |     | acc_pt1.5                           |    0.97904 |
# |     | adjusted_mutual_info                |    0.00000 |
# |     | adjusted_rand                       |    0.00000 |
# |     | background                          |    0.99809 |
# |     | background_train                    |    0.99693 |
# |     | background_weighted                 |    0.99809 |
# |     | background_weighted_train           |    0.99693 |
# |     | best_dbscan_eps                     |    0.97619 |
# |     | best_dbscan_min_samples             |    1.00000 |
# |     | completeness                        |    1.00000 |
# |     | fowlkes_mallows                     |    0.07140 |
# |     | homogeneity                         |    0.00000 |
# |     | potential_attractive                |    0.00000 |
# |     | potential_attractive_train          |    0.00000 |
# |     | potential_attractive_weighted       |    1.29111 |
# |     | potential_attractive_weighted_train |    1.02912 |
# |     | potential_repulsive                 |  116.49876 |
# |     | potential_repulsive_train           |   15.22751 |
# |     | potential_repulsive_weighted        | 1164.98758 |
# |     | potential_repulsive_weighted_train  |  152.27512 |
# |     | roc_auc_10FPR_pt0.9                 |    0.50000 |
# |     | roc_auc_10FPR_pt1.5                 |    0.50000 |
# |     | roc_auc_20FPR_pt0.9                 |    0.50000 |
# |     | roc_auc_20FPR_pt1.5                 |    0.50000 |
# |     | roc_auc_5FPR_pt0.9                  |    0.50000 |
# |     | roc_auc_5FPR_pt1.5                  |    0.50000 |
# |     | roc_auc_pt0.9                       |    0.50000 |
# |     | roc_auc_pt1.5                       |    0.50000 |
# |     | tc_FNR_pt0.9                        |    1.00000 |
# |     | tc_FNR_pt1.5                        |    1.00000 |
# |     | tc_FPR_pt0.9                        |    0.00000 |
# |     | tc_FPR_pt1.5                        |    0.00000 |
# |     | tc_TNR_pt0.9                        |    1.00000 |
# |     | tc_TNR_pt1.5                        |    1.00000 |
# | --> | tc_TPR_pt0.9                        |    0.00000 |
# | --> | tc_TPR_pt1.5                        |    0.00000 |
# |     | tc_acc_pt0.9                        |    0.81821 |
# |     | tc_acc_pt1.5                        |    0.87737 |
# |     | tc_adjusted_mutual_info             |    0.00000 |
# |     | tc_adjusted_rand                    |    0.00000 |
# |     | tc_background                       |    0.99740 |
# |     | tc_background_weighted              |    0.99740 |
# |     | tc_best_dbscan_eps                  |    0.96988 |
# |     | tc_best_dbscan_min_samples          |    1.00000 |
# |     | tc_completeness                     |    1.00000 |
# |     | tc_fowlkes_mallows                  |    0.16070 |
# |     | tc_homogeneity                      |    0.00000 |
# |     | tc_potential_attractive             |    0.00000 |
# |     | tc_potential_attractive_weighted    |    1.36177 |
# |     | tc_potential_repulsive              |   16.09320 |
# |     | tc_potential_repulsive_weighted     |  160.93205 |
# |     | tc_roc_auc_10FPR_pt0.9              |    0.50000 |
# |     | tc_roc_auc_10FPR_pt1.5              |    0.50000 |
# |     | tc_roc_auc_20FPR_pt0.9              |    0.50000 |
# |     | tc_roc_auc_20FPR_pt1.5              |    0.50000 |
# |     | tc_roc_auc_5FPR_pt0.9               |    0.50000 |
# |     | tc_roc_auc_5FPR_pt1.5               |    0.50000 |
# |     | tc_roc_auc_pt0.9                    |    0.50000 |
# |     | tc_roc_auc_pt1.5                    |    0.50000 |
# |     | tc_total                            |  163.29121 |
# | --> | tc_trk.double_majority              |    0.00000 |
# | --> | tc_trk.double_majority_pt0.5        |    0.00000 |
# | --> | tc_trk.double_majority_pt0.9        |    0.00000 |
# | --> | tc_trk.double_majority_pt1.5        |    0.00000 |
# | --> | tc_trk.fake_double_majority         |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt0.5   |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt0.9   |    0.02353 |
# | --> | tc_trk.fake_double_majority_pt1.5   |    0.02421 |
# |     | tc_trk.fake_lhc                     |    1.00000 |
# |     | tc_trk.fake_lhc_pt0.5               |    1.00000 |
# |     | tc_trk.fake_lhc_pt0.9               |    1.00000 |
# |     | tc_trk.fake_lhc_pt1.5               |    1.00000 |
# |     | tc_trk.fake_perfect                 |    0.02353 |
# |     | tc_trk.fake_perfect_pt0.5           |    0.02353 |
# |     | tc_trk.fake_perfect_pt0.9           |    0.02353 |
# |     | tc_trk.fake_perfect_pt1.5           |    0.02421 |
# |     | tc_trk.lhc                          |    0.00000 |
# |     | tc_trk.lhc_pt0.5                    |    0.00000 |
# |     | tc_trk.lhc_pt0.9                    |    0.00000 |
# |     | tc_trk.lhc_pt1.5                    |    0.00000 |
# |     | tc_trk.n_cleaned_clusters           |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt0.5     |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt0.9     |    1.00000 |
# |     | tc_trk.n_cleaned_clusters_pt1.5     |    0.39130 |
# |     | tc_trk.n_particles                  |   44.68116 |
# |     | tc_trk.n_particles_pt0.5            |   44.68116 |
# |     | tc_trk.n_particles_pt0.9            |   44.68116 |
# |     | tc_trk.n_particles_pt1.5            |   16.37681 |
# |     | tc_trk.perfect                      |    0.00000 |
# |     | tc_trk.perfect_pt0.5                |    0.00000 |
# |     | tc_trk.perfect_pt0.9                |    0.00000 |
# |     | tc_trk.perfect_pt1.5                |    0.00000 |
# |     | tc_v_measure                        |    0.00000 |
# |     | total                               | 1167.27677 |
# |     | total_train                         |  154.30117 |
# | --> | trk.double_majority                 |    0.00000 |
# | --> | trk.double_majority_pt0.5           |    0.00000 |
# | --> | trk.double_majority_pt0.9           |    0.00000 |
# | --> | trk.double_majority_pt1.5           |    0.00000 |
# | --> | trk.fake_double_majority            |    0.00434 |
# | --> | trk.fake_double_majority_pt0.5      |    0.00227 |
# | --> | trk.fake_double_majority_pt0.9      |    0.00144 |
# | --> | trk.fake_double_majority_pt1.5      |    0.00230 |
# |     | trk.fake_lhc                        |    1.00000 |
# |     | trk.fake_lhc_pt0.5                  |    1.00000 |
# |     | trk.fake_lhc_pt0.9                  |    1.00000 |
# |     | trk.fake_lhc_pt1.5                  |    1.00000 |
# |     | trk.fake_perfect                    |    0.00434 |
# |     | trk.fake_perfect_pt0.5              |    0.00227 |
# |     | trk.fake_perfect_pt0.9              |    0.00144 |
# |     | trk.fake_perfect_pt1.5              |    0.00230 |
# |     | trk.lhc                             |    0.00000 |
# |     | trk.lhc_pt0.5                       |    0.00000 |
# |     | trk.lhc_pt0.9                       |    0.00000 |
# |     | trk.lhc_pt1.5                       |    0.00000 |
# |     | trk.n_cleaned_clusters              |    1.00000 |
# |     | trk.n_cleaned_clusters_pt0.5        |    0.23188 |
# |     | trk.n_cleaned_clusters_pt0.9        |    0.07246 |
# |     | trk.n_cleaned_clusters_pt1.5        |    0.04348 |
# |     | trk.n_particles                     |  235.69565 |
# |     | trk.n_particles_pt0.5               |  107.79710 |
# |     | trk.n_particles_pt0.9               |   44.68116 |
# |     | trk.n_particles_pt1.5               |   16.37681 |
# |     | trk.perfect                         |    0.00000 |
# |     | trk.perfect_pt0.5                   |    0.00000 |
# |     | trk.perfect_pt0.9                   |    0.00000 |
# |     | trk.perfect_pt1.5                   |    0.00000 |
# |     | v_measure                           |    0.00000 |
# +-----+-------------------------------------+------------+
